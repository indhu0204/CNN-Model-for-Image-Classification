# %% [markdown]
# # Introduction
# Accurate and timely weather prediction can provide critical information for businesses in fields such as agriculture and transportation. This information can be used to make informed decisions and take necessary actions to mitigate potential risks. However, traditional weather forecasting methods can be limited in their accuracy and efficiency. They also require massive models which perform predictions using complex physical relationships and a large number of independent variables. By leveraging the power of deep learning techniques such as convolutional neural networks (CNNs), the accuracy of weather prediction can be improved and businesses can be equipped with more reliable and real time forecasts.

# %% [markdown]
# ## Problem Statement
# Task is to develop a CNN model that can accurately classify landscape images based on the weather in the captured image.

# %% [markdown]
# ## Outline
# The overall objective of this assignment is to build a CNN model to classify landscape images based on the weather captured in an image. The different stages involved in the process are outlined below:
#
# - Stage 1 - Setup
#   - Task 1 - Import required modules
#   - Task 2 - Load the data
#   - Task 3 - Explore the data
# - Stage 2 - Data preparation
#   - Task 4 - Resize all images to the same dimensions
#   - Task 5 - Prepare the data for feeding into CNNs
# - Stage 3 - Simple model
#   - Task 6 - Define a function to build a CNN model
#   - Task 7 - Create a simple CNN model and analyze its performance
# - Stage 4 - Data augmentation
#   - Task 8 - Create a transformed image
#   - Task 9 - Divide the data by class
#   - Task 10 - Augment the training data
#   - Task 11 - Create a simple CNN model using the augmented data and analyze its performance
# - Stage 5 - Optimal model
#   - Task 12 - Tune the CNN model
# - Stage 6 - Testing
#   - Task 13 - Train your optimal model satisfactorily

# %% [markdown]
# # Stage 1 - Setup
# In this stage, you will set up the environment for this assignment by loading the required methods and the data required to train your model. You will explore the data set by displaying some images and examining attributes of different variables. You will achieve all of this by completing the following three tasks:
# - Task 1 - Import required modules
# - Task 2 - Load the data
# - Task 3 - Explore the data

# %% [markdown]
# ## Task 1 - Import required modules

# %% [markdown]
# ### Description
# In this task, you will load all the methods and packages required to perform the various tasks in this assignment.

# %% [markdown]
# ### Requirements
# Writing a code that can be used to import the following list of methods and packages that are required in this assignment:
#
# - Handling raw data files: *os*
# - Working with numbers and data frames: *numpy* and *pandas*
# - Visualizing data: *pyplot* (from *matplotlib*) and *seaborn*
# - Utilities for handling images (from *tensorflow.keras.utils*):
#  - *img_to_array*
#  - *array_to_img*
#  - *load_img*
# - Augmenting image data: *tensorflow.image*
# - Processing data:
#   - *LabelEncoder* (from *sklearn.preprocessing*)
#   - *to_categorical* (from *tensorflow.keras.utils*)
#   - *train_test_split* (from *sklearn.model_selection*)
#
# - Creating CNN models:
#  - *Sequential* (from *tensorflow.keras.models*)
#  - *Input*, *Dense*, *Conv2D*, *MaxPooling2D*, *Flatten* (from *tensorflow.keras.layers*)
#  - *Adam* (from *tensorflow.keras.optimizers*)
#
# - Suppressing warnings:
#  - *warnings*

# %% [markdown]
# First, import the required packages and modules.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.utils import img_to_array, array_to_img, load_img
import tensorflow.image as tfi
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Now write code to suppress warnings.

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Checklist
#
# - Imported the required packages
# - Suppressed warnings

# %% [markdown]
# ## Task 2 - Load the data

# %% [markdown]
# ### Description
#
# In this task, you will ensure that data is available in the environment at the right place and write a function to load the data into memory. We recommend that you either use Jupyter Notebook or Google Colab to build and execute your code.
#
# If you are using Google Colab to execute your code, you can simply the upload the zip file containing the data to your Google Drive and mount your Google Drive in your Colab VM to access the data.

# %% [markdown]
# ### Requirements
# - In case you are using Google Colab, import *drive* from *google.colab* and mount your Google Drive.
# - In case you are using Jupyter Notebook, please make sure that your files and folders are all in the right place.
# - Define a function *load_data()*:
#  - The function must read all the images and their corresponding labels from the appropriate folders and store them in two lists, one for the images, and the other one for the labels.
#  - It should have the following keyword argument:
#    - *mainfolder*: A string that describes the address of the parent data folder in the memory.
#  - It should have the following return values:
#    - *list_of_images*: A list containing PIL image instances for each image.
#    - *image_labels*: A list containing their respective labels in the form of a string.

# %% [markdown]
# ### Recommendations
# - If you are using Google Colab:
#   - Upload the zip file containing the data in Google Drive and then unzip it using *unzip* shell command which you can access using the *!* (exclamation mark) character.
#   - Once you have mounted Google Drive into your Google Colab VM, you can use the Files section on the left to access the filesystem. You can right click on a file or folder to copy its path. This will be useful while specifying the source file in the *unzip* shell command.
#   - To specify the target path, you can create a new folder in the folder where your zip file is located.
#   - Similarly, you can copy the exact location of the *train* and *test* folders. You will need to pass the locations into the *load_data()* function to load the training and test data respectively.
# - If you are running this code locally, you can unzip the zip folder locally into a folder on your system and copy the path of the parent folder from there.
# - Inside the *load_data()* function, you can:
#  - use the *os.listdir()* method to obtain the names of the files and folders within a particular folder.
#  - use the *load_img()* method that you imported earlier to read and store images in a variable in the PIL Image format.

# %% [markdown]
# First, if you are using Google Colab, mount Google Drive to your VM. If not, skip and comment out this cell.

# %% [markdown]
# If you are using Colab, after mounting the drive you need to unzip the files to extract all the images inside it. Note that you don't need to perform this step more than once, so we recommend that you comment out your code for this step once it has executed.

# %% [markdown]
# Now define the *load_data()* function.

# %%
import os
from tensorflow.keras.utils import load_img

def load_data(mainfolder):
    '''
    Loads the images from the main folder (train or test) and creates a list
    containing PIL Image instances for each image, as well as their labels.
    
    Args:
        mainfolder: A string that describes the address of the train/test folder.
    
    Returns:
        list_of_images: A list containing PIL Image instances for each image.
        image_labels: A list containing the respective labels (as a string).
    '''
    
    list_of_images = []
    image_labels = []
    
    # Loop through each class folder (sunny, rainy, cloudy)
    for folder in os.listdir(mainfolder):
        folder_path = os.path.join(mainfolder, folder)
        
        if os.path.isdir(folder_path):  # Check if it's a folder
            # Loop through each image file in the subfolder
            for img_file in os.listdir(folder_path):
                img_path = os.path.join(folder_path, img_file)
                
                # Load the image and store it
                img = load_img(img_path)
                list_of_images.append(img)
                
                # Append the folder name (i.e., 'sunny', 'rainy', 'cloudy') as the label
                image_labels.append(folder)
    
    return list_of_images, image_labels

# Example usage:
# Load training data
train_folder = r"C:\Users\HP\Downloads\Files\weatherdata\weather\train"
train_images, train_labels = load_data(train_folder)

# %% [markdown]
# Finally, use the *load_data()* function to load the training and testing data.

# %%
# Use this cell to load the training and testing data sets and store them in the appropriate variables
train_folder = r"C:\Users\HP\Downloads\Files\weatherdata\weather\train"
test_folder = r"C:\Users\HP\Downloads\Files\weatherdata\weather\test"
# Load the training data
X_train, y_train = load_data(train_folder)

# Load the testing data
X_test, y_test = load_data(test_folder)

# Check the loaded data
print(f"Number of training samples: {len(X_train)}")
print(f"Number of testing samples: {len(X_test)}")
print(f"Unique training labels: {set(y_train)}")
print(f"Unique testing labels: {set(y_test)}")
# Out:
# Number of training samples: 505
# Number of testing samples: 45
# Unique training labels: {'sunny', 'rainy', 'cloudy'}
# Unique testing labels: {'sunny', 'rainy', 'cloudy'}

# %% [markdown]
# ### Checklist
# - Defined the *load_data()* function which takes in the given keyword arguments and returns the given variables
# - Used the *load_data()* function to load *X_train, y_train, X_test,* and *y_test*
# - *X_train, y_train, X_test,* and *y_test* are of the type *list*
# - Items in *X_train* and *X_test* are of the type *PIL.JpegImagePlugin.JpegImageFile*
# - Items in *y_train* and *y_test* are of the type *str*

# %% [markdown]
# ## Task 3 - Explore the data

# %% [markdown]
# ### Description
#
# In this task, you will explore the data that you have just loaded. To this end, you will display one image from each class from both the training and the testing data sets. To inspect the size of the data sets, you will examine the number of data points available in the training and the testing data sets. You will also save the number of classes present in the data set in a variable for later use. Finally, you will count the number of records that belong to different classes in the training data set and represent this information in a histogram.
#
# The number of records in different classes allows us to study the class balance in the data set. An imbalanced data set will cause the model to be biased in favor of the classes with high representation. This is an important aspect of the data set that must be considered.

# %% [markdown]
# ### Requirements
# - View an image from each class in the training and the testing data sets.
# - Print the length of *X_train, y_train, X_test,* and *y_test*.
# - Save the number of classes present in the data set in a variable called *n_classes*.
# - Print the number of elements in each class in the training and testing data sets.
# - Visualize the class balance using a histogram.

# %% [markdown]
# ### Recommendations
#
# - You can use the *imshow()* method from *matplotlib.pyplot* to view images.
# - The number of subfolders in either the training or testing folders is equal to the number of classes. You can use a combination of the *os.listdir()* and the *len()* methods to obtain the number of classes.
# - You can use the *unique()* method from *numpy* to obtain the unique items in an array along with their corresponding occurence frequencies in that array.
# - You can use the *countplot()* function from *seaborn* to create the histogram.

# %% [markdown]
# First, display images from the training and testing data sets.

# %%
# Use this cell to view a few images from the training data set for each class

def view_sample_images(data, labels, classes, title="Training Data"):
    plt.figure(figsize=(10, 5))
    for i, cls in enumerate(classes):
        idx = labels.index(cls)  # Find index of the first occurrence of the class
        plt.subplot(1, len(classes), i+1)
        plt.imshow(data[idx])
        plt.title(cls)
        plt.axis('off')
    plt.suptitle(title)
    plt.show()

# %%
# Assuming y_train contains class labels, and X_train contains images
classes = list(set(y_train))
view_sample_images(X_train, y_train, classes, title="Training Data")

# %%
# Use this cell to view a few images from the testing data set for each class

view_sample_images(X_test, y_test, classes, title="Testing Data")

# %% [markdown]
# Print the number of training and testing data points available to you.

# %%
# Use this cell to inspect the number of training and testing data points available

print(f'Number of training data points: {len(X_train)}')
print(f'Number of testing data points: {len(X_test)}')
# Out:
# Number of training data points: 505
# Number of testing data points: 45

# %% [markdown]
# Store the number of classes in this classification exercise.

# %%
# Use this cell to extract and store the total class count

# Extract and store the total class count
n_classes = len(set(y_train))
print('Number of classes =', n_classes)
# Out:
# Number of classes = 3

# %% [markdown]
# Print the number of data points from each class in the training and testing data sets.

# %%
# Use this cell to inspect the number of training and testing data points available in each class

# Print the number of data points from each class in the training data set
import numpy as np

# Get unique class names and their counts
unique_train, counts_train = np.unique(y_train, return_counts=True)
unique_test, counts_test = np.unique(y_test, return_counts=True)

# Display number of data points in each class
print("Training Data Class Counts:")
for cls, count in zip(unique_train, counts_train):
    print(f'{cls}: {count} samples')

print("\nTesting Data Class Counts:")
for cls, count in zip(unique_test, counts_test):
    print(f'{cls}: {count} samples')
# Out:
# Training Data Class Counts:
# cloudy: 285 samples
# rainy: 70 samples
# sunny: 150 samples
#
# Testing Data Class Counts:
# cloudy: 15 samples
# rainy: 15 samples
# sunny: 15 samples

# %% [markdown]
# Finally, visualze the class balance in the training data set.

# %%
# Use this cell to visualize the class balance in the training data set

import seaborn as sns

plt.figure(figsize=(8, 5))
sns.countplot(x=y_train, order=np.unique(y_train))
plt.title("Class Distribution in Training Data")
plt.xlabel("Weather Class")
plt.ylabel("Number of Samples")
plt.show()

# %% [markdown]
# ### Checklist
# - Viewed one sample image from each class for training and testing data sets
# - Length of *X_train* is 505
# - Length of *X_test* is 45
# - The "cloudy" class has 285 data points in the training data set
# - The "rainy" class has 70 data points in the training data set
# - The "sunny" class has 150 data points in the training data set
# - Created a visualization for class balance in the training data set

# %% [markdown]
# # Stage 2 - Data Preparation
# In this stage, you will perform some basic essential data preparation methods on your image data so that they are ready for use in CNNs.
#
# To prepare the data, you will first need to resize the images in the training and testing data sets to the same size. This can be done using some methods provided to us in the *tensorflow* library. Second, you will convert the data into a format that is suitable to be fed into a Keras CNN model.
#
# You will achieve this by completing the following tasks:
# - Task 4 - Resize all images to the same dimension
# - Task 5 - Prepare the data for feeding into CNN

# %% [markdown]
# ## Task 4 - Resize all images to the same dimensions

# %% [markdown]
# ### Description
# In this task, you will resize all the images in your data set to the same dimensions. This is necessary because CNN models expect input images to have the same dimensions.
#
# You will first need to choose the dimensions of the resized images. It is recommened to reshape all the images to squares as it is easier to work with square images. Thererfore, to choose the side of the square, you need to inspect the dimensions of all the images in your data sets. You can pick any size that is smaller than the smallest image in the original data set as this generally ensures better data retention.
#
# Note that resizing the image to the chosen dimension will have an impact on the rest of the assignment. Smaller image sizes will lead to less complex models and faster training, but the consequent data loss might lead to information loss, that might affect model performance. On the other hand, larger image dimensions will lead to more complex models and slower training, but there is lower risk of information loss, and that might lead to better model performance. You can change the dimensions of your resized images keeping in mind the trade off between performance and information loss.
# For this, you can revisit this task after training a simple model try different image dimensions (that are smaller than the smallest dimension in the original data set).
#
# Once you have decided on the new size, you can use any method of your choice to obtain the smallest dimensions in the training and testing data set images.
#
# Finally, you will save your training image list and the corresponding labels in new variables which can be accessed later. This is required because you will soon perform a set of data preprocessing steps on the training data, but when you get to the augmentation stage, you will need to retrieve the unprocessed training data.

# %% [markdown]
# ### Requirements
# - Find the smallest image dimension (considering both length and width) in both the training and the testing data sets.
# - Choose the new dimensions for the images in the data set and save them in a variable *new_image_dims*.
# - Define a function *resize_images()*:
#     - The function must resize all the images in a list of images and return the updated list of images with the resized images. The function should be able to resize images in both the training and testing data sets.
#     - The function should have the following keyword arguments:
#         - *input_images*: A list of input images to be resized. Each input image must be a PIL image.
#         - *new_dims*: An integer specifying the desired dimensions of the output images. Each output image will have the same height and width.
#     - The function should return the following:
#          - *resized_images*: A list of resized images. Each output image is a PIL image with the specified dimensions.
# - Use the *resize_images()* function to resize images from the training and testing data sets.
# - View an image from each class in the training and the testing data sets.
# - Save the training data set containing resized images into new variables *X_pre_NN* and *y_pre_NN*. This is to retain the training data in its image format before proceeding with data preprocessing for CNNs.

# %% [markdown]
# ### Recommendations
# - You can use the *size* attribute of PIL Image objects to access the dimensions of an image in the form of a tuple.
# - If you convert a list to a set, only the unique items in the list are present in the resultant set. You can use this to find out the unique image sizes in the data sets.
# - Since you are reshaping images to squares, you can specify the new image dimension as a whole number instead of a tuple.
# - You can use the *resize()* method from *tensorflow.image* to resize an image.
# - You can use the *img_to_array()* method to convert an image to an array before using the *resize()* method on it.
# - You can use the *array_to_img()* method to convert an array to an image after the *resize()* method operation.
# - Start by resizing your images to 64 pixels by 64 pixels. You may revisit this after training a simple model to try different sizes.

# %% [markdown]
# First, obtain the smallest image dimensions in training and testing data sets.

# %%
# Use this cell to obtain the smallest image dimensions in the training and testing data sets

smallest_train_dim = min([min(image.size) for image in X_train])
smallest_test_dim = min([min(image.size) for image in X_test])

print(f'Smallest image dimension in training data: {smallest_train_dim}')
print(f'Smallest image dimension in testing data: {smallest_test_dim}')
# Out:
# Smallest image dimension in training data: 111
# Smallest image dimension in testing data: 160

# %% [markdown]
# Now define the *resize_images()* function.

# %%
import tensorflow as tf 
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
import numpy as np

# Define a function that resizes image dimensions
def resize_images(input_images, new_dims):
    '''
    Resizes all the images in a list to a square with its side given.
    
    Args:
        input_images: A list of images to be resized. Each input image must be a PIL image.
        new_dims: An integer specifying the desired dimensions of the output images. 
                  Each output image will have the same height and width.
    
    Returns:
        resized_images: A list of resized images. Each output image is a PIL image with 
                        the specified dimensions.
    '''
    resized_images = []
    for img in input_images:
        img_array = img_to_array(img)  # Convert the image to array
        resized_img_array = tf.image.resize(img_array, [new_dims, new_dims])  # Resize
        resized_img = array_to_img(resized_img_array)  # Convert array back to image
        resized_images.append(resized_img)
    
    return resized_images

# %% [markdown]
# Next, decide on a new image dimension.

# %%
# Use this cell to set the new dimensions for all images

# Set the new dimensions for all images
new_image_dims = 64

# %% [markdown]
# Use the *resize_images()* method to resize your training and testing images.

# %%
# Use this cell to standardize the dimensions for all images in the training and testing data sets

# Standardize the dimensions for all images in the training data set
X_train = resize_images(X_train, new_image_dims)

# Standardize the dimensions for all images in the testing data set
X_test = resize_images(X_test, new_image_dims)

# %% [markdown]
# View some images from the resized data set.

# %%
# Use this cell to view a few images from the training data set for each class
view_sample_images(X_train, y_train, classes, title="Resized Training Data")

# %%
# Use this cell to view a few images from the testing data set for each class

view_sample_images(X_test, y_test, classes, title="Resized Testing Data")

# %% [markdown]
# Finally, save the resized data set into variables that will be useful later.

# %%
# Use this cell to store the resized images and labels for later use

# Store the resized images for later use
X_pre_NN = X_train

# Store the labels for later use
y_pre_NN = y_train

# %% [markdown]
# ### Checklist
# - Smallest image dimension in the training data is 111
# - Smallest image dimension in the testing data is 160
# - Defined the *resize_images()* function using the given keyword arguments and return variables
# - Declared the new image dimension in a variable called *new_image_dims*
# - Resized images in both *X_train* and *X_test*
# - Saved the resized data sets into new variables for later use

# %% [markdown]
# ## Task 5 - Prepare the data for feeding into CNN

# %% [markdown]
# ### Description
#
# In this section, you will perform a set of data preparation steps that enables CNNs to work on the data. Currently, *X_train* and *X_test* are lists of images, whereas *y_train* and *y_test* are lists of strings. Keras models can accept data in the form of *numpy* arrays. Therefore, you will convert the data into arrays.
#
# For the input data, you need to convert the list of images into an *numpy* array. Note that the pixel gray levels are currently in the range $[0, 255]$. You will rescale these to $[0, 1]$. This is a common pre-processing step in image classification tasks, as it helps the model to converge faster during training.
#
# For the output data, you will need to encode the different labels as one-hot encoded vectors.

# %% [markdown]
# ### Requirements
# - Convert *X_train* and *X_test* and their constituent images to *numpy* arrays.
# - Scale *X_train* and *X_test* by divding the pixel values by 255.
# - Perform one-hot encoding on *y_train* and *y_test*.
# - Store the expected input shape for the CNN in a variable called *inputdims*.

# %% [markdown]
# ### Recommendations
# - You can convert images to arrays using the *img_to_array()* method.
# - You can then convert the list of arrays into an array using the *numpy.array()* method.
# - You can use the *LabelEncoder()* method to encode labels into integers You can then use the *to_categorical()* method to convert these integer labels into one-hot encoded vectors.

# %% [markdown]
# First, convert the input data into numpy arrays.

# %%
# Use this cell to convert the training and testing images into arrays

X_train = np.array([img_to_array(img) for img in X_train])
X_test = np.array([img_to_array(img) for img in X_test])

# %% [markdown]
# Now, rescale the data.

# %%
# Use this cell to rescale the training and testing images from the range [0, 255] to [0, 1]

X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %% [markdown]
# Now convert the image labels to one-hot encoded vectors.

# %%
# Use this cell to one-hot encode the labels in the training and testing data sets
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)  # Convert labels to integers
y_test_encoded = label_encoder.transform(y_test)

# Convert to one-hot encoded vectors
y_train = to_categorical(y_train_encoded)
y_test = to_categorical(y_test_encoded)

# %% [markdown]
# Finally, save the input dimensions for the CNNs in a variable so that you can call or refer to it when building CNN models.

# %%
# Use this cell to store the input dimensions for the CNNs

# Store the input dimensions for the CNNs
inputdims = X_train.shape[1:]  # (64, 64, 3)

# %%
# Printing to verify shapes
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
print("inputdims:", inputdims)
# Out:
# X_train shape: (505, 64, 64, 3)
# X_test shape: (45, 64, 64, 3)
# y_train shape: (505, 3)
# y_test shape: (45, 3)
# inputdims: (64, 64, 3)

# %% [markdown]
# ### Checklist
# - *X_train* is an *ndarray* of shape $(505, 64, 64, 3)$
# - *X_test* is an *ndarray* of shape $(45, 64, 64, 3)$
# - Values in *X_train* and *X_test* range from $0$ to $1$
# - *y_train* is an *ndarray* of shape $(505, 3)$
# - *y_test* is an *ndarray* of shape $(45, 3)$
# - Values in *y_train* and *y_test* are either $0$ or $1$
# - *inputdims* contains the expected shape of the input for a CNN model, and is equal to $(64, 64, 3)$

# %% [markdown]
# # Stage 3 - Simple Model
# In this stage, you will build, train and evaluate a basic CNN model on the data and analyze its performance. You will build the model using a function. This will help you change the configuration of your model during execution. You will also test the performance of the performance of the model by training it multiple times and then judging the distribution of final accuracies and loss values.
#
# You will do all this with the help of the following tasks:
# - Task 6 - Define a function to build a CNN model
# - Task 7 - Create a simple CNN model and analyze its performance

# %% [markdown]
# ## Task 6 - Define a function to build a CNN model

# %% [markdown]
# ### Description
# In this task, you will define a function that creates a CNN model, compiles it, and returns the compiled model.
#
# You will need an easy way to create models with different configurations and hyperparameter values when you perform hyperparameter tuning. Therefore, it is useful to define a build function for your CNN model that let's you control the network configuration and returns the model.

# %% [markdown]
# ### Requirements
# - Define a function *create_cnn()*:
#     - This function creates and compiles a convolutional neural network (CNN) with the specified layers configuration and learning rate.
#     - The function should have the following keyword arguments:
#         - *layers_config*: A list of strings specifying the configuration of each layer in the CNN. This parameter should be interpreted by the function to add convolutional, pooling, flatten and dense layers along with their parameters such as filter size, filter stride, number of filters, number of neurons and so on, and a learning rate value parameter.
#         - *learning_rate_value*: A float specifying the learning rate to be used by the optimizer during training.
#     - The function should return the following:
#         - *cnn*: A compiled CNN with the specified configuration of layers and learning rate.

# %% [markdown]
# ### Recommendations
# - Consider an example for the *layers_config* variable. A *Conv2d()* layer may be represented using the string *c_4_3*. This could be interpreted as follows: *c* stands for the layer being a *Conv2D()* layer, 4 stands for the number of filters in the layer and 3 is used to define the size of the filter. Therefore if the string *c_4_3* is an item in the list *layers_config*, it should add the following layer: *Conv2D(filters = 4, kernel_size = 3)*. Similarly you can define string patterns for other layers.
# - It is recommended to use the following specifications as fixed specifications of the CNN models:
#     - The input layer can be fixed and the input dimensions that you saved in the variable *inputdims* can be provided into this layer.
#     - The activation function for the dense layers may be fixed as ReLU.
#     - The output layer can be fixed as a dense layer with the appropriate number of output neurons and the activation function for this layer can be fixed as Softmax.
#     - When compiling the network, the loss function can be fixed as categorical crossentropy, the metric can be fixed as accuracy, and the optimizer type may be fixed as Adam.
#     - Any other parameter that has not been explicitly mentioned in this assignment may be left at their default values.

# %% [markdown]
# Define the *create_cnn()* function.

# %%
# Use this cell to define a function that creates and compiles a CNN

# Define a function that creates and compiles a CNN
def create_cnn(layers_config, learning_rate_value):
    '''
    Creates and compiles a convolutional neural network (CNN) with the specified layers configuration and learning rate.
    
    Args:
        layers_config: A list of strings specifying the configuration of each layer in the CNN.
        learning_rate_value: A float specifying the learning rate to be used by the optimizer during training.
    
    Returns:
        cnn: A compiled CNN with the specified layers configuration and learning rate.
    '''

    cnn = Sequential()

    # Input layer (fix input dimensions)
    cnn.add(Conv2D(filters=layers_config[0]['filters'], 
                   kernel_size=layers_config[0]['kernel_size'], 
                   activation='relu', 
                   input_shape=inputdims))

    # Iterate over the layers configuration to add layers dynamically
    for layer in layers_config[1:]:
        if layer['type'] == 'conv':
            cnn.add(Conv2D(filters=layer['filters'], 
                           kernel_size=layer['kernel_size'], 
                           activation='relu'))
        elif layer['type'] == 'pool':
            cnn.add(MaxPooling2D(pool_size=layer['pool_size']))
        elif layer['type'] == 'flatten':
            cnn.add(Flatten())
        elif layer['type'] == 'dense':
            cnn.add(Dense(units=layer['units'], activation='relu'))
    
    # Output layer (fixed as per task description)
    cnn.add(Dense(units=3, activation='softmax'))  # Assuming 3 classes

    # Compile the CNN model
    optimizer = Adam(learning_rate=learning_rate_value)
    cnn.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return cnn

# %% [markdown]
# ### Checklist
# - Defined a function *create_cnn()* with given keyword arguments and return variables
# - Followed the recommended specifications in the model

# %% [markdown]
# ## Task 7 - Create a simple CNN model and analyze its performance

# %% [markdown]
# ### Description
#
# In this task, you will create a simple CNN model and train it on the training data multiple times and record its performance in each training iteration. You will then analyze the model's performance by summarizing its performance over the various training trials.
#
# The reason why we want to train it multiple times is that your model may not train the same way each time. To get a good understanding of a model's performance, you need to train it a few times under the same settings and conditions and record its performance each time. You can then judge the model based on the distribution of its performances.

# %% [markdown]
# ### Requirements
# - Store the number of trials, number of epochs, and the validation split in variables called *num_trials*, *n_epochs*, and *val_split* respectively. These variables can be globally used throughout the code.
# - Use the *create_cnn()* function to create a basic CNN model. You may start off with the following suggested network specifications:
#     - A convolutional layer with 2 filters, each of size 3 and stride 1
#     - A max pooling layer with size 2 and stride 1
#     - Another convolutional layer with 4 filters, each of size 3 and stride 1
#     - Another max pooling layer with size 2 and stride 1
#     - A flatten layer
#     - A dense layer with 8 neurons
# - Build and train the network multiple times and record the performance of each training instance of the model in a data frame called *performance_df*.

# %% [markdown]
# ### Recommendations
# - You may start off with 10 trials for the remainder of this assignment. You could rerun your code (once it is complete) and check your model performance for 10, 15, 20 trials and so on.
# - You may start off with 10 epochs for the remainder of this assignment, but you are free to rerun your code (once it is complete) and check your results for 10, 15, 20 epochs and so on.
# - We also recommend that you use a validation split fraction of 0.2 for all the model fit commands in this assignment.
# - You may use any method of your choice to record the performance of your model over different trials, but you are advised to report the *performance_df* data frame in the format described below at the end of the complete training process.
#   - For instance, if the number of training trials for a model is 3, then its performance data frame format should be as follows:
#     - Index column name: Trial Number
#     - Index column entries: 1, 2, 3, Mean, Median, Max
#     - First column: Training Accuracy
#     - Second column: Validation Accuracy

# %% [markdown]
# First, save the number of trials in a variable.

# %%
# Use this cell to set the number of trials for each model training instance

# Set the number of trials for each model training instance
num_trials = 10

# %% [markdown]
# Now save the number of epochs and the validation split in a variable.

# %%
# Use this cell to set the number of CNN training epochs and the validation split fraction

# Set the number of epochs for CNN training
n_epochs = 10

# Set the validation split fraction
val_split = 0.2

# %%
# Suggested CNN network configuration
layers_config = [
    {'type': 'conv', 'filters': 2, 'kernel_size': 3},   # Conv Layer with 2 filters, kernel size 3x3
    {'type': 'pool', 'pool_size': 2},                   # Max Pooling Layer with size 2x2
    {'type': 'conv', 'filters': 4, 'kernel_size': 3},   # Conv Layer with 4 filters, kernel size 3x3
    {'type': 'pool', 'pool_size': 2},                   # Max Pooling Layer with size 2x2
    {'type': 'flatten'},                                # Flattening Layer
    {'type': 'dense', 'units': 8}                       # Dense Layer with 8 neurons
]

# %% [markdown]
# Finally, create train and evaluate your CNN model.

# %%
# Use this cell to create, train and evaluate your simple CNN model on the data multiple times and store and view the performance results

# Function to train the model for a single trial
def train_cnn_model(trial_num):
    # Create the CNN model
    model = create_cnn(layers_config=layers_config, learning_rate_value=0.001)

    # Train the model
    history = model.fit(X_train, y_train, epochs=n_epochs, validation_split=val_split, verbose=0)

    # Extract the performance metrics
    train_acc = history.history['accuracy'][-1]
    val_acc = history.history['val_accuracy'][-1]
    
    return train_acc, val_acc

# Initialize an empty list to store performance data
performance_data = []

# Run multiple trials and store the performance
for trial in range(1, num_trials + 1):
    train_acc, val_acc = train_cnn_model(trial)
    performance_data.append([trial, train_acc, val_acc])

# Convert the performance data to a DataFrame
performance_df = pd.DataFrame(performance_data, columns=['Trial Number', 'Training Accuracy', 'Validation Accuracy'])

# Calculate summary statistics
mean_train_acc = performance_df['Training Accuracy'].mean()
mean_val_acc = performance_df['Validation Accuracy'].mean()

median_train_acc = performance_df['Training Accuracy'].median()
median_val_acc = performance_df['Validation Accuracy'].median()

max_train_acc = performance_df['Training Accuracy'].max()
max_val_acc = performance_df['Validation Accuracy'].max()

# Append the summary statistics to the DataFrame
performance_df.loc['Mean'] = ['Mean', mean_train_acc, mean_val_acc]
performance_df.loc['Median'] = ['Median', median_train_acc, median_val_acc]
performance_df.loc['Max'] = ['Max', max_train_acc, max_val_acc]

# Display the performance DataFrame
print(performance_df)
# Out:
#        Trial Number  Training Accuracy  Validation Accuracy
# 0                 1           0.821782             0.000000
# 1                 2           0.774752             0.128713
# 2                 3           0.779703             0.000000
# 3                 4           0.727723             0.019802
# 4                 5           0.779703             0.000000
# 5                 6           0.705446             0.000000
# 6                 7           0.725248             0.000000
# 7                 8           0.705446             0.000000
# 8                 9           0.705446             0.000000
# 9                10           0.710396             0.000000
# Mean           Mean           0.743564             0.014851
# Median       Median           0.726485             0.000000
# Max             Max           0.821782             0.128713

# %% [markdown]
# Looking at the *performance_df* data frame, you should be able to conclude that the model seems to be performing reasonably well on the training data, but its performance is very poor on the validation data.
#
# There is a high likelihood that the class imbalance in the data set is contributing to this poor performance.
#
# Also, it wouldn't be incorrect to say that the training data size is quite less.
#
# One way to resolve these issues is to perform data augmentation. This will increase the size of the training data set so that the model will have enough data to train on. Using augmentation, we can also ensure that the classes in the training data are balanced.

# %% [markdown]
# ### Checklist
# - Saved values for number of trials, number of epochs, and validation split in variables
# - Created and trained a simple CNN model multiple times and evaluated its performance
# - Displayed the model's performance over multiple trials and the summary statistics in the given format

# %% [markdown]
# # Stage 4 - Data Augmentation
# Data augmentation is a technique that is commonly used in deep learning to artificially increase the size of the training data set.
#
# You can add augmented images to your your training data to improve the class balance in the training data set and also to increase the size of the training data.
#
# In this stage, you will augment your training data to increase the training data size and improve the class balance in the training data set. You will then retrain your basic CNN model on the augmented data set and analyze its performance over multiple training trials.
#
# In the first three tasks of this stage, you will write functions and helper functions to perform data augmentation. Whereas in the fourth task, you will use those functions to actually perform data augmentation. The tasks are given below:
# - Task 8 - Create a transformed image
# - Task 9 - Divide the data according to class
# - Task 10 - Augment the data
# - Task 11 - Create a simple CNN model using the augmented data and analyze its performance

# %% [markdown]
# ## Task 8 - Create a transformed image

# %% [markdown]
# ### Description
# In the case of image classification, data augmentation is done by applying random transformations to the images in the training data set, such as rotation, flipping, and zooming. By doing so, the model is exposed to a greater variety of training samples, which can help improve its ability to generalize to unseen data.
#
# In this task, you will define a function to randomly transform a given image using one of the predefined transformations. This function will be used later to augment the data.
#
# But recall that we performed some data preparation steps on our data set in Task 5. Recall also that we saved our data in two variables *X_pre_NN* and *y_pre_NN*. We will perform data augmentation using this unprocessed data.

# %% [markdown]
# ### Requirements
# - Retrieve the training data from the variables *X_pre_NN* and *y_pre_NN*.
# - Define a function *random_transform()*:
#     - This function takes in an input image and creates a new image out of it using some random augmentation technique.
#     - The function should have the following keyword argument:
#         - *input_image*: A PIL image object over which the random transformation will be applied.
#     - The function should return the following:
#         - *output_image*: A PIL image object, the augmented image.
# - Verify the function by visualizing a few images before transformation and after transformation

# %% [markdown]
# ### Recommendations
# - You can retrieve the original data from the variables *X_pre_NN* and *y_pre_NN* and save them in the variables *X_train* and *y_train* respectively.
# - In the *random_transform()* function, to create a new image from an existing image, you can use the *flip_left_right()*, the *flip_up_down()* and the *rot90()* methods from *tensorflow.image*.
# - Recall that you will need to use the *img_to_array()* and the *array_to_img()* methods wherever applicable to perform various operations.
# - You will have to introduce some randomness into the augmentation process so that your code randomly performs one of the following augmentations on the input image:
#   - flip left and right
#   - flip up and down
#   - rotate 90 degrees (either clockwise or counter-clockwise) once, twice, or thrice

# %% [markdown]
# Retrieve the training data that you saved in an earlier stage before conducting data preparation on it for feeding into CNNs.

# %%
# Use this cell to retrieve the training data that you saved in an earlier stage

# Retrieve the training images
X_train = X_pre_NN

# Retrieve the training labels
y_train = y_pre_NN

# %% [markdown]
# Now, define the function *random_transform()* that takes in an image and creates a new image from it using a random transformation.

# %%
# Use this cell to define a function that takes in an input image and creates a new image out of it using some random augmentation

# Define a function that takes in an input image and creates a new image out of it using some random augmentation
def random_transform(input_image):
    """
    Takes in an input image and applies a random transformation to it.
    
    Args:
        input_image: A PIL image object.
        
    Returns:
        output_image: A PIL image object, the augmented image.
    """
    # Convert PIL image to array
    image_array = img_to_array(input_image)
    
    # Randomly choose a transformation
    transform_choice = random.choice(['flip_left_right', 'flip_up_down', 'rotate_90', 'rotate_180', 'rotate_270'])
    
    if transform_choice == 'flip_left_right':
        transformed_array = tf.image.flip_left_right(image_array)
    elif transform_choice == 'flip_up_down':
        transformed_array = tf.image.flip_up_down(image_array)
    elif transform_choice == 'rotate_90':
        transformed_array = tf.image.rot90(image_array, k=1)  # Rotate 90 degrees
    elif transform_choice == 'rotate_180':
        transformed_array = tf.image.rot90(image_array, k=2)  # Rotate 180 degrees
    elif transform_choice == 'rotate_270':
        transformed_array = tf.image.rot90(image_array, k=3)  # Rotate 270 degrees
    
    # Convert array back to a PIL image
    output_image = array_to_img(transformed_array)
    
    return output_image

# %% [markdown]
# You can now test your function on any input image and view the results. Note that if you defined your function correctly, each time you run the following cell, a random augmentation would be performed.

# %%
# Use this cell to apply the "random_transform()" function on an image and view the results
# Note: This is a sample execution and the actual augmentation function will be defined in Task 10

##### CODE HERE #####
import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
import random  # Import the random module
import matplotlib.pyplot as plt

# Choose a random image from the training set
sample_image = array_to_img(X_train[0])

# Apply random transformation
augmented_image = random_transform(sample_image)

# Display original and augmented images side by side
plt.figure(figsize=(6, 3))

# Original image
plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(sample_image)

# Augmented image
plt.subplot(1, 2, 2)
plt.title('Augmented Image')
plt.imshow(augmented_image)

plt.show()

# %% [markdown]
# ### Checklist
# - Retrieved data stored in *X_pre_NN* and *y_pre_NN*
# - Defined the *random_transform()* function using the keyword arguments and return variables described above
# - Experimented with the *random_transform()* function and verified that the function randomly augments an input image

# %% [markdown]
# ## Task 9 - Divide the data by class

# %% [markdown]
# ### Description
#
# Recall the countplot that you created earlier that represented the number of elements in the training data set belonging ot the different classes.
#
# ![countplot class imbalance.png](data:image/png;base64,...)
#
# As you have seen before in the bar graph given above, there is class imbalance in the data set. Moreover, the total number of records in the train data set is small at 550. Since we want to augment the training data such that all the classes have the same number of samples, we need to create new images for the different classes separately as we will need to increase the number of images in the three data sets by a different number in each data set. So, it is benefical to define a helper function that divides the training data into its respective classes.
#
# In this task, you will define the *divide_data_by_class()* helper function that does this.
#
# The main function will then use these two helper functions (*random_transform()* and *divide_data_by_class()*) to augment the training data set with additional images such that:
# 1.   All the classes have the same number of samples
# 2.   The total amount of training data is larger than the original training data set
#
# Now, you will define the *divide_data_by_class()* helper function that divides the input images and their labels into sublists based on their corresponding class labels. Given the original list of all images and the list of their corresponding labels, as the output of this function, you need to create three lists of images and the respective three lists of labels corresponding to the three unique labels present in our data set. Before returning the data, you can save the three image lists in a list and the three label lists in another list.

# %% [markdown]
# ### Requirements
# - Visualize the class balance using a histogram.
# - Define a function *divide_data_by_class()*:
#     - This function divides the input images and labels into subsets based on their corresponding class labels.
#     - The function should have the following keyword arguments:
#         - *input_images*: A list of input images to be divided based on class labels. Each input image must be a PIL image.
#         - *image_labels*: A list that contains corresponding labels for each image in input_images. Each label is a string.
#     - The function should return the following:
#         - *classwise_images*: A list of lists, where each sublist contains the input images corresponding to a unique class label.
#         - *classwise_labels*: A list of lists, where each sublist contains the labels corresponding to the input images in classwise_images list.

# %% [markdown]
# ### Recommendations
#
# - In the *divide_data_by_class()* function, to divide the training data set into respective classes, you will need the unique class labels and their frequencies. This can be obtained using the *numpy.unique()* method.

# %% [markdown]
# Visualize the class balance in the training data set using a bar plot or a count plot.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Assuming y_train contains the labels of the training images
unique_classes, counts = np.unique(y_train, return_counts=True)

# Visualize the class balance using a bar plot
plt.figure(figsize=(8, 4))
sns.barplot(x=unique_classes, y=counts)
plt.title("Class Distribution in Training Data")
plt.xlabel("Classes")
plt.ylabel("Number of Images")
plt.show()

# %% [markdown]
# You can see that the classes in the training data are quite imbalanced. Moreover, the number of training samples is quite small as well.

# %% [markdown]
# Now, define the function *divide_data_by_class()* that divides the input images and labels into subsets based on their corresponding class labels.

# %%
# Use this cell to define a function that takes in the list of training images and labels and returns them class-wise

# Define a function that takes in the list of training images and returns them class-wise
# Function to divide data by class
def divide_data_by_class(input_images, image_labels):
    """
    Divides the input images and labels into subsets based on their corresponding class labels.

    Args:
        input_images: A list of input images (PIL images) to be divided based on class labels.
        image_labels: A list of class labels corresponding to the input images.

    Returns:
        classwise_images: A list of lists, where each sublist contains the input images corresponding to a unique class label.
        classwise_labels: A list of lists, where each sublist contains the labels corresponding to the input images in classwise_images.
    """
    # Get the unique class labels
    unique_labels = np.unique(image_labels)
    
    # Initialize empty lists to hold the classwise images and labels
    classwise_images = [[] for _ in range(len(unique_labels))]
    classwise_labels = [[] for _ in range(len(unique_labels))]
    
    # Iterate over the input images and labels
    for image, label in zip(input_images, image_labels):
        # Find the index of the class label
        class_index = np.where(unique_labels == label)[0][0]
        
        # Append the image and label to the respective sublist
        classwise_images[class_index].append(image)
        classwise_labels[class_index].append(label)
    
    return classwise_images, classwise_labels

# %% [markdown]
# You can now use the *divide_data_by_class()* function on the data set and view the results.

# %%
# Use this cell to divide the training data into its respective classes and labels
# Note: This is a sample execution and the actual augmentation function will be defined in Task 10

# Divide the data into classes
classwise_images, classwise_labels = divide_data_by_class(X_train, y_train)

# Output the number of images in each class
for i, class_label in enumerate(unique_classes):
    print(f"Class {class_label}: {len(classwise_images[i])} images")
# Out:
# Class cloudy: 285 images
# Class rainy: 70 images
# Class sunny: 150 images

# %% [markdown]
# ### Checklist
# - Visualized class balance in the data set
# - The *divide_data_by_class()* function returns two lists that contain three lists each
# - Experimented with the *divide_data_by_class()* function and ensured that it is functioning properly

# %% [markdown]
# ## Task 10 - Augment the training data

# %% [markdown]
# ### Description
#
# With these two functions, *random_transform()* and *divide_data_by_class()* in hand, you can define the main augmentation function called *augment_data()*. This function takes in an image data set and the factor by which the data set needs to be augmented. This function should:
# 1. Divide the data set into different classes using the *divide_data_by_class()* function.
# 2. Calculate the final size of each class. This is done by multiplying the factor by the size of the largest class.
# 3. Use the *random_transform()* function to create images till all three classes achieve the required size.
#
# After defining the function, try augmenting the data set and visualize the class balance again to verify your results

# %% [markdown]
# ### Requirements
# - Define a function *augment_data()*:
#     - This function augments the training data by applying random transformations until all classes in the training data have the same number of data points and ensures that the number of data points in each class is a multiple of the size of the largest class in the original data set. The multiplication factor is user-controlled.
#     - The function should have the following keyword arguments:
#         - *input_images*: A list of input images.
#         - *image_labels*: A list of labels for the input images.
#         - *data_size_factor*: A scaling factor for the size of the augmented data. This will be used to calculate the final size of each class by multiplying *data_size_factor* with the size of the largest class and then rounding to the nearest integer.
# - Use the *augment_data()* function to augment the training data set.
# - Visualize the class balance using a histogram after augmentation.

# %% [markdown]
# ### Recommendations
# - In the *augment_data()* function, use the *divide_data_by_class()* function that you defined earlier to divide the input data into their respective classes. This way, it should be easier for you to bring all the classes to the same size using the *random_transform()* function that you defined earlier.
# - You will need to introduce some randomness into your code so that a random image from the original data set is selected for augmentation each time.
# - You should also ensure that an augmented image is ***not*** considered for augmentation again.
# - The data size incrementation factor parameter can be considered as a kind of multiplier, that is, if your original class balance is **[x, y, z]** where **x**, **y** and **z** are the numbers of data points in each of the classes, and **x** is the largest for instance, and your parameter value is 2, then the output class balance should be **[2x, 2x, 2x]**.
# - After the class-wise augmentation is done, remember to put everything together into a single list of augmented training images (similarly for the list of labels).

# %% [markdown]
# Define the *augment_data()* function that works on the original training data and produces an augmented training data set from it.

# %%
import numpy as np
import random
from tqdm import tqdm  # Optional for progress tracking

def augment_data(input_images, image_labels, data_size_factor=1):
    """
    Augments the training data by applying random transformations until all classes 
    have the same number of data points.
    
    Args:
        input_images: A list of input images.
        image_labels: A list of labels corresponding to the input images.
        data_size_factor: A scaling factor for the size of the augmented data.
                          The final size of each class will be the size of the 
                          largest class multiplied by this factor.
    
    Returns:
        new_images: The augmented images.
        new_labels: The labels corresponding to the new images.
    """
    
    # Step 1: Divide the dataset by class using divide_data_by_class()
    classwise_images, classwise_labels = divide_data_by_class(input_images, image_labels)
    
    # Step 2: Get the size of the largest class
    largest_class_size = max(len(class_images) for class_images in classwise_images)
    target_class_size = int(largest_class_size * data_size_factor)
    
    # Lists to store the new images and labels after augmentation
    new_images = []
    new_labels = []
    
    # Step 3: Augment the data for each class
    for class_images, class_labels in tqdm(zip(classwise_images, classwise_labels), total=len(classwise_images), desc="Augmenting data"):
        # Add original images and labels to the new dataset
        new_images.extend(class_images)
        new_labels.extend(class_labels)
        
        # Calculate how many more images are needed for this class
        num_new_images = target_class_size - len(class_images)
        
        # Randomly augment the existing images to fill up the class
        for _ in range(num_new_images):
            # Select a random image from the class
            random_idx = random.randint(0, len(class_images) - 1)
            random_image = class_images[random_idx]
            
            # Apply random transformation using random_transform()
            augmented_image = random_transform(random_image)
            
            # Add the augmented image and the corresponding label to the dataset
            new_images.append(augmented_image)
            new_labels.append(class_labels[0])  # All labels in this list are the same
    
    return new_images, new_labels

# %% [markdown]
# Use the *augment_data()* function to augment the training data.

# %%
# Use this cell to augment your training data

# Augment your training data using the "augment_data()" function
# Define your data size factor (e.g., 2x the size of the largest class)
data_size_factor = 2

# Augment the training data
X_train_augmented, y_train_augmented = augment_data(X_train, y_train, data_size_factor)
# Out:
# Augmenting data: 100%|███████████| 3/3 [00:03<00:00,  1.02s/it]

# %% [markdown]
# Visualize the class balance in the augmented training data set using a bar plot or a count plot.

# %%
# Use this cell to visualize the class balance in the training data set

# Visualize the class balance after augmentation
augmented_classes, augmented_counts = np.unique(y_train_augmented, return_counts=True)

plt.figure(figsize=(8, 4))
sns.barplot(x=augmented_classes, y=augmented_counts)
plt.title("Class Distribution After Data Augmentation")
plt.xlabel("Classes")
plt.ylabel("Number of Images")
plt.show()

# %% [markdown]
# ### Checklist
# - Experimented with the *augment_data()* function and made sure that it is working properly
#   - For example, if the *augment_data()* function is used on the original training data with a *data_size_factor* of 1, each class in the output data has 285 images, and the total number of images in the new list is 855. If *data_size_factor* was 2 instead, then each class in the output data has 570 images, and the total number images in the new list is 1710.
# - Decided on a suitable value for the augmentation factor and augmented the training data

# %% [markdown]
# ## Task 11 - Create a simple CNN model using the augmented data and analyze its performance

# %% [markdown]
# ### Description
# In this task, you will retrain your simple CNN model multiple times using the augmented data and record its performance in each training instance. You will then analyze its performance by summarizing its performance over the multiple training trials.
#
# But before you do that, you will need to perform all the data prepration steps that you did earlier so that the data is ready to be fed into CNNs.

# %% [markdown]
# ### Requirements
# - Perform the data preparation steps from Stage 2 again.
# - Create, train, and analyze the performance of a simple CNN model.

# %% [markdown]
# ### Recommendations
# - You may reuse code from Task 5 for data preparation, but make sure that all the variable names are correct.
# - You may reuse code from Task 7 to create, train, and analyze the performance of the model, but make sure that all the variable names are correct.
# - You may want to try augmenting your data using different values for *data_size_factor* to improve the accuracy of your model.

# %%
# Use this cell to rescale the training images from the range [0, 255] to [0, 1]
# Use this cell to one-hot encode the labels in the training data set
# Use this cell to create, train and evaluate your simple CNN model on the augmented data multiple times and store the performance results

# %%
# Check the size of each PIL image in X_train_augmented
for i, img in enumerate(X_train_augmented):
    print(f"Image {i} size: {img.size}")  # .size gives (width, height)
# Out:
# Image 0 size: (64, 64)
# Image 1 size: (64, 64)
# Image 2 size: (64, 64)
# Image 3 size: (64, 64)
# Image 4 size: (64, 64)
# Image 5 size: (64, 64)
# Image 6 size: (64, 64)
# Image 7 size: (64, 64)
# Image 8 size: (64, 64)
# Image 9 size: (64, 64)
# Image 10 size: (64, 64)
# Image 11 size: (64, 64)
# Image 12 size: (64, 64)
# Image 13 size: (64, 64)
# Image 14 size: (64, 64)
# Image 15 size: (64, 64)
# Image 16 size: (64, 64)
# Image 17 size: (64, 64)
# Image 18 size: (64, 64)
# Image 19 size: (64, 64)
# Image 20 size: (64, 64)
# Image 21 size: (64, 64)
# Image 22 size: (64, 64)
# Image 23 size: (64, 64)
# Image 24 size: (64, 64)
# Image 25 size: (64, 64)
# Image 26 size: (64, 64)
# Image 27 size: (64, 64)
# Image 28 size: (64, 64)
# Image 29 size: (64, 64)
# Image 30 size: (64, 64)
# Image 31 size: (64, 64)
# Image 32 size: (64, 64)
# Image 33 size: (64, 64)
# Image 34 size: (64, 64)
# Image 35 size: (64, 64)
# Image 36 size: (64, 64)
# Image 37 size: (64, 64)
# Image 38 size: (64, 64)
# Image 39 size: (64, 64)
# Image 40 size: (64, 64)
# Image 41 size: (64, 64)
# Image 42 size: (64, 64)
# Image 43 size: (64, 64)
# Image 44 size: (64, 64)
# Image 45 size: (64, 64)
# Image 46 size: (64, 64)
# Image 47 size: (64, 64)
# Image 48 size: (64, 64)
# Image 49 size: (64, 64)
# Image 50 size: (64, 64)
# Image 51 size: (64, 64)
# Image 52 size: (64, 64)
# Image 53 size: (64, 64)
# Image 54 size: (64, 64)
# Image 55 size: (64, 64)
# Image 56 size: (64, 64)
# Image 57 size: (64, 64)
# Image 58 size: (64, 64)
# Image 59 size: (64, 64)
# Image 60 size: (64, 64)
# Image 61 size: (64, 64)
# Image 62 size: (64, 64)
# Image 63 size: (64, 64)
# Image 64 size: (64, 64)
# Image 65 size: (64, 64)
# Image 66 size: (64, 64)
# Image 67 size: (64, 64)
# Image 68 size: (64, 64)
# Image 69 size: (64, 64)
# Image 70 size: (64, 64)
# Image 71 size: (64, 64)
# Image 72 size: (64, 64)
# Image 73 size: (64, 64)
# Image 74 size: (64, 64)
# Image 75 size: (64, 64)
# Image 76 size: (64, 64)
# Image 77 size: (64, 64)
# Image 78 size: (64, 64)
# Image 79 size: (64, 64)
# Image 80 size: (64, 64)
# Image 81 size: (64, 64)
# Image 82 size: (64, 64)
# Image 83 size: (64, 64)
# Image 84 size: (64, 64)
# Image 85 size: (64, 64)
# Image 86 size: (64, 64)
# Image 87 size: (64, 64)
# Image 88 size: (64, 64)
# Image 89 size: (64, 64)
# Image 90 size: (64, 64)
# Image 91 size: (64, 64)
# Image 92 size: (64, 64)
# Image 93 size: (64, 64)
# Image 94 size: (64, 64)
# Image 95 size: (64, 64)
# Image 96 size: (64, 64)
# Image 97 size: (64, 64)
# Image 98 size: (64, 64)
# Image 99 size: (64, 64)
# Image 100 size: (64, 64)
# Image 101 size: (64, 64)
# Image 102 size: (64, 64)
# Image 103 size: (64, 64)
# Image 104 size: (64, 64)
# Image 105 size: (64, 64)
# Image 106 size: (64, 64)
# Image 107 size: (64, 64)
# Image 108 size: (64, 64)
# Image 109 size: (64, 64)
# Image 110 size: (64, 64)
# Image 111 size: (64, 64)
# Image 112 size: (64, 64)
# Image 113 size: (64, 64)
# Image 114 size: (64, 64)
# Image 115 size: (64, 64)
# Image 116 size: (64, 64)
# Image 117 size: (64, 64)
# Image 118 size: (64, 64)
# Image 119 size: (64, 64)
# Image 120 size: (64, 64)
# Image 121 size: (64, 64)
# Image 122 size: (64, 64)
# Image 123 size: (64, 64)
# Image 124 size: (64, 64)
# Image 125 size: (64, 64)
# Image 126 size: (64, 64)
# Image 127 size: (64, 64)
# Image 128 size: (64, 64)
# Image 129 size: (64, 64)
# Image 130 size: (64, 64)
# Image 131 size: (64, 64)
# Image 132 size: (64, 64)
# Image 133 size: (64, 64)
# Image 134 size: (64, 64)
# Image 135 size: (64, 64)
# Image 136 size: (64, 64)
# Image 137 size: (64, 64)
# Image 138 size: (64, 64)
# Image 139 size: (64, 64)
# Image 140 size: (64, 64)
# Image 141 size: (64, 64)
# Image 142 size: (64, 64)
# Image 143 size: (64, 64)
# Image 144 size: (64, 64)
# Image 145 size: (64, 64)
# Image 146 size: (64, 64)
# Image 147 size: (64, 64)
# Image 148 size: (64, 64)
# Image 149 size: (64, 64)
# Image 150 size: (64, 64)
# Image 151 size: (64, 64)
# Image 152 size: (64, 64)
# Image 153 size: (64, 64)
# Image 154 size: (64, 64)
# Image 155 size: (64, 64)
# Image 156 size: (64, 64)
# Image 157 size: (64, 64)
# Image 158 size: (64, 64)
# Image 159 size: (64, 64)
# Image 160 size: (64, 64)
# Image 161 size: (64, 64)
# Image 162 size: (64, 64)
# Image 163 size: (64, 64)
# Image 164 size: (64, 64)
# Image 165 size: (64, 64)
# Image 166 size: (64, 64)
# Image 167 size: (64, 64)
# Image 168 size: (64, 64)
# Image 169 size: (64, 64)
# Image 170 size: (64, 64)
# Image 171 size: (64, 64)
# Image 172 size: (64, 64)
# Image 173 size: (64, 64)
# Image 174 size: (64, 64)
# Image 175 size: (64, 64)
# Image 176 size: (64, 64)
# Image 177 size: (64, 64)
# Image 178 size: (64, 64)
# Image 179 size: (64, 64)
# Image 180 size: (64, 64)
# Image 181 size: (64, 64)
# Image 182 size: (64, 64)
# Image 183 size: (64, 64)
# Image 184 size: (64, 64)
# Image 185 size: (64, 64)
# Image 186 size: (64, 64)
# Image 187 size: (64, 64)
# Image 188 size: (64, 64)
# Image 189 size: (64, 64)
# Image 190 size: (64, 64)
# Image 191 size: (64, 64)
# Image 192 size: (64, 64)
# Image 193 size: (64, 64)
# Image 194 size: (64, 64)
# Image 195 size: (64, 64)
# Image 196 size: (64, 64)
# Image 197 size: (64, 64)
# Image 198 size: (64, 64)
# Image 199 size: (64, 64)
# Image 200 size: (64, 64)
# Image 201 size: (64, 64)
# Image 202 size: (64, 64)
# Image 203 size: (64, 64)
# Image 204 size: (64, 64)
# Image 205 size: (64, 64)
# Image 206 size: (64, 64)
# Image 207 size: (64, 64)
# Image 208 size: (64, 64)
# Image 209 size: (64, 64)
# Image 210 size: (64, 64)
# Image 211 size: (64, 64)
# Image 212 size: (64, 64)
# Image 213 size: (64, 64)
# Image 214 size: (64, 64)
# Image 215 size: (64, 64)
# Image 216 size: (64, 64)
# Image 217 size: (64, 64)
# Image 218 size: (64, 64)
# Image 219 size: (64, 64)
# Image 220 size: (64, 64)
# Image 221 size: (64, 64)
# Image 222 size: (64, 64)
# Image 223 size: (64, 64)
# Image 224 size: (64, 64)
# Image 225 size: (64, 64)
# Image 226 size: (64, 64)
# Image 227 size: (64, 64)
# Image 228 size: (64, 64)
# Image 229 size: (64, 64)
# Image 230 size: (64, 64)
# Image 231 size: (64, 64)
# Image 232 size: (64, 64)
# Image 233 size: (64, 64)
# Image 234 size: (64, 64)
# Image 235 size: (64, 64)
# Image 236 size: (64, 64)
# Image 237 size: (64, 64)
# Image 238 size: (64, 64)
# Image 239 size: (64, 64)
# Image 240 size: (64, 64)
# Image 241 size: (64, 64)
# Image 242 size: (64, 64)
# Image 243 size: (64, 64)
# Image 244 size: (64, 64)
# Image 245 size: (64, 64)
# Image 246 size: (64, 64)
# Image 247 size: (64, 64)
# Image 248 size: (64, 64)
# Image 249 size: (64, 64)
# Image 250 size: (64, 64)
# Image 251 size: (64, 64)
# Image 252 size: (64, 64)
# Image 253 size: (64, 64)
# Image 254 size: (64, 64)
# Image 255 size: (64, 64)
# Image 256 size: (64, 64)
# Image 257 size: (64, 64)
# Image 258 size: (64, 64)
# Image 259 size: (64, 64)
# Image 260 size: (64, 64)
# Image 261 size: (64, 64)
# Image 262 size: (64, 64)
# Image 263 size: (64, 64)
# Image 264 size: (64, 64)
# Image 265 size: (64, 64)
# Image 266 size: (64, 64)
# Image 267 size: (64, 64)
# Image 268 size: (64, 64)
# Image 269 size: (64, 64)
# Image 270 size: (64, 64)
# Image 271 size: (64, 64)
# Image 272 size: (64, 64)
# Image 273 size: (64, 64)
# Image 274 size: (64, 64)
# Image 275 size: (64, 64)
# Image 276 size: (64, 64)
# Image 277 size: (64, 64)
# Image 278 size: (64, 64)
# Image 279 size: (64, 64)
# Image 280 size: (64, 64)
# Image 281 size: (64, 64)
# Image 282 size: (64, 64)
# Image 283 size: (64, 64)
# Image 284 size: (64, 64)
# Image 285 size: (64, 64)
# Image 286 size: (64, 64)
# Image 287 size: (64, 64)
# Image 288 size: (64, 64)
# Image 289 size: (64, 64)
# Image 290 size: (64, 64)
# Image 291 size: (64, 64)
# Image 292 size: (64, 64)
# Image 293 size: (64, 64)
# Image 294 size: (64, 64)
# Image 295 size: (64, 64)
# Image 296 size: (64, 64)
# Image 297 size: (64, 64)
# Image 298 size: (64, 64)
# Image 299 size: (64, 64)
# Image 300 size: (64, 64)
# Image 301 size: (64, 64)
# Image 302 size: (64, 64)
# Image 303 size: (64, 64)
# Image 304 size: (64, 64)
# Image 305 size: (64, 64)
# Image 306 size: (64, 64)
# Image 307 size: (64, 64)
# Image 308 size: (64, 64)
# Image 309 size: (64, 64)
# Image 310 size: (64, 64)
# Image 311 size: (64, 64)
# Image 312 size: (64, 64)
# Image 313 size: (64, 64)
# Image 314 size: (64, 64)
# Image 315 size: (64, 64)
# Image 316 size: (64, 64)
# Image 317 size: (64, 64)
# Image 318 size: (64, 64)
# Image 319 size: (64, 64)
# Image 320 size: (64, 64)
# Image 321 size: (64, 64)
# Image 322 size: (64, 64)
# Image 323 size: (64, 64)
# Image 324 size: (64, 64)
# Image 325 size: (64, 64)
# Image 326 size: (64, 64)
# Image 327 size: (64, 64)
# Image 328 size: (64, 64)
# Image 329 size: (64, 64)
# Image 330 size: (64, 64)
# Image 331 size: (64, 64)
# Image 332 size: (64, 64)
# Image 333 size: (64, 64)
# Image 334 size: (64, 64)
# Image 335 size: (64, 64)
# Image 336 size: (64, 64)
# Image 337 size: (64, 64)
# Image 338 size: (64, 64)
# Image 339 size: (64, 64)
# Image 340 size: (64, 64)
# Image 341 size: (64, 64)
# Image 342 size: (64, 64)
# Image 343 size: (64, 64)
# Image 344 size: (64, 64)
# Image 345 size: (64, 64)
# Image 346 size: (64, 64)
# Image 347 size: (64, 64)
# Image 348 size: (64, 64)
# Image 349 size: (64, 64)
# Image 350 size: (64, 64)
# Image 351 size: (64, 64)
# Image 352 size: (64, 64)
# Image 353 size: (64, 64)
# Image 354 size: (64, 64)
# Image 355 size: (64, 64)
# Image 356 size: (64, 64)
# Image 357 size: (64, 64)
# Image 358 size: (64, 64)
# Image 359 size: (64, 64)
# Image 360 size: (64, 64)
# Image 361 size: (64, 64)
# Image 362 size: (64, 64)
# Image 363 size: (64, 64)
# Image 364 size: (64, 64)
# Image 365 size: (64, 64)
# Image 366 size: (64, 64)
# Image 367 size: (64, 64)
# Image 368 size: (64, 64)
# Image 369 size: (64, 64)
# Image 370 size: (64, 64)
# Image 371 size: (64, 64)
# Image 372 size: (64, 64)
# Image 373 size: (64, 64)
# Image 374 size: (64, 64)
# Image 375 size: (64, 64)
# Image 376 size: (64, 64)
# Image 377 size: (64, 64)
# Image 378 size: (64, 64)
# Image 379 size: (64, 64)
# Image 380 size: (64, 64)
# Image 381 size: (64, 64)
# Image 382 size: (64, 64)
# Image 383 size: (64, 64)
# Image 384 size: (64, 64)
# Image 385 size: (64, 64)
# Image 386 size: (64, 64)
# Image 387 size: (64, 64)
# Image 388 size: (64, 64)
# Image 389 size: (64, 64)
# Image 390 size: (64, 64)
# Image 391 size: (64, 64)
# Image 392 size: (64, 64)
# Image 393 size: (64, 64)
# Image 394 size: (64, 64)
# Image 395 size: (64, 64)
# Image 396 size: (64, 64)
# Image 397 size: (64, 64)
# Image 398 size: (64, 64)
# Image 399 size: (64, 64)
# Image 400 size: (64, 64)
# Image 401 size: (64, 64)
# Image 402 size: (64, 64)
# Image 403 size: (64, 64)
# Image 404 size: (64, 64)
# Image 405 size: (64, 64)
# Image 406 size: (64, 64)
# Image 407 size: (64, 64)
# Image 408 size: (64, 64)
# Image 409 size: (64, 64)
# Image 410 size: (64, 64)
# Image 411 size: (64, 64)
# Image 412 size: (64, 64)
# Image 413 size: (64, 64)
# Image 414 size: (64, 64)
# Image 415 size: (64, 64)
# Image 416 size: (64, 64)
# Image 417 size: (64, 64)
# Image 418 size: (64, 64)
# Image 419 size: (64, 64)
# Image 420 size: (64, 64)
# Image 421 size: (64, 64)
# Image 422 size: (64, 64)
# Image 423 size: (64, 64)
# Image 424 size: (64, 64)
# Image 425 size: (64, 64)
# Image 426 size: (64, 64)
# Image 427 size: (64, 64)
# Image 428 size: (64, 64)
# Image 429 size: (64, 64)
# Image 430 size: (64, 64)
# Image 431 size: (64, 64)
# Image 432 size: (64, 64)
# Image 433 size: (64, 64)
# Image 434 size: (64, 64)
# Image 435 size: (64, 64)
# Image 436 size: (64, 64)
# Image 437 size: (64, 64)
# Image 438 size: (64, 64)
# Image 439 size: (64, 64)
# Image 440 size: (64, 64)
# Image 441 size: (64, 64)
# Image 442 size: (64, 64)
# Image 443 size: (64, 64)
# Image 444 size: (64, 64)
# Image 445 size: (64, 64)
# Image 446 size: (64, 64)
# Image 447 size: (64, 64)
# Image 448 size: (64, 64)
# Image 449 size: (64, 64)
# Image 450 size: (64, 64)
# Image 451 size: (64, 64)
# Image 452 size: (64, 64)
# Image 453 size: (64, 64)
# Image 454 size: (64, 64)
# Image 455 size: (64, 64)
# Image 456 size: (64, 64)
# Image 457 size: (64, 64)
# Image 458 size: (64, 64)
# Image 459 size: (64, 64)
# Image 460 size: (64, 64)
# Image 461 size: (64, 64)
# Image 462 size: (64, 64)
# Image 463 size: (64, 64)
# Image 464 size: (64, 64)
# Image 465 size: (64, 64)
# Image 466 size: (64, 64)
# Image 467 size: (64, 64)
# Image 468 size: (64, 64)
# Image 469 size: (64, 64)
# Image 470 size: (64, 64)
# Image 471 size: (64, 64)
# Image 472 size: (64, 64)
# Image 473 size: (64, 64)
# Image 474 size: (64, 64)
# Image 475 size: (64, 64)
# Image 476 size: (64, 64)
# Image 477 size: (64, 64)
# Image 478 size: (64, 64)
# Image 479 size: (64, 64)
# Image 480 size: (64, 64)
# Image 481 size: (64, 64)
# Image 482 size: (64, 64)
# Image 483 size: (64, 64)
# Image 484 size: (64, 64)
# Image 485 size: (64, 64)
# Image 486 size: (64, 64)
# Image 487 size: (64, 64)
# Image 488 size: (64, 64)
# Image 489 size: (64, 64)
# Image 490 size: (64, 64)
# Image 491 size: (64, 64)
# Image 492 size: (64, 64)
# Image 493 size: (64, 64)
# Image 494 size: (64, 64)
# Image 495 size: (64, 64)
# Image 496 size: (64, 64)
# Image 497 size: (64, 64)
# Image 498 size: (64, 64)
# Image 499 size: (64, 64)
# Image 500 size: (64, 64)
# Image 501 size: (64, 64)
# Image 502 size: (64, 64)
# Image 503 size: (64, 64)
# Image 504 size: (64, 64)
# Image 505 size: (64, 64)
# Image 506 size: (64, 64)
# Image 507 size: (64, 64)
# Image 508 size: (64, 64)
# Image 509 size: (64, 64)
# Image 510 size: (64, 64)
# Image 511 size: (64, 64)
# Image 512 size: (64, 64)
# Image 513 size: (64, 64)
# Image 514 size: (64, 64)
# Image 515 size: (64, 64)
# Image 516 size: (64, 64)
# Image 517 size: (64, 64)
# Image 518 size: (64, 64)
# Image 519 size: (64, 64)
# Image 520 size: (64, 64)
# Image 521 size: (64, 64)
# Image 522 size: (64, 64)
# Image 523 size: (64, 64)
# Image 524 size: (64, 64)
# Image 525 size: (64, 64)
# Image 526 size: (64, 64)
# Image 527 size: (64, 64)
# Image 528 size: (64, 64)
# Image 529 size: (64, 64)
# Image 530 size: (64, 64)
# Image 531 size: (64, 64)
# Image 532 size: (64, 64)
# Image 533 size: (64, 64)
# Image 534 size: (64, 64)
# Image 535 size: (64, 64)
# Image 536 size: (64, 64)
# Image 537 size: (64, 64)
# Image 538 size: (64, 64)
# Image 539 size: (64, 64)
# Image 540 size: (64, 64)
# Image 541 size: (64, 64)
# Image 542 size: (64, 64)
# Image 543 size: (64, 64)
# Image 544 size: (64, 64)
# Image 545 size: (64, 64)
# Image 546 size: (64, 64)
# Image 547 size: (64, 64)
# Image 548 size: (64, 64)
# Image 549 size: (64, 64)
# Image 550 size: (64, 64)
# Image 551 size: (64, 64)
# Image 552 size: (64, 64)
# Image 553 size: (64, 64)
# Image 554 size: (64, 64)
# Image 555 size: (64, 64)
# Image 556 size: (64, 64)
# Image 557 size: (64, 64)
# Image 558 size: (64, 64)
# Image 559 size: (64, 64)
# Image 560 size: (64, 64)
# Image 561 size: (64, 64)
# Image 562 size: (64, 64)
# Image 563 size: (64, 64)
# Image 564 size: (64, 64)
# Image 565 size: (64, 64)
# Image 566 size: (64, 64)
# Image 567 size: (64, 64)
# Image 568 size: (64, 64)
# Image 569 size: (64, 64)
# Image 570 size: (64, 64)
# Image 571 size: (64, 64)
# Image 572 size: (64, 64)
# Image 573 size: (64, 64)
# Image 574 size: (64, 64)
# Image 575 size: (64, 64)
# Image 576 size: (64, 64)
# Image 577 size: (64, 64)
# Image 578 size: (64, 64)
# Image 579 size: (64, 64)
# Image 580 size: (64, 64)
# Image 581 size: (64, 64)
# Image 582 size: (64, 64)
# Image 583 size: (64, 64)
# Image 584 size: (64, 64)
# Image 585 size: (64, 64)
# Image 586 size: (64, 64)
# Image 587 size: (64, 64)
# Image 588 size: (64, 64)
# Image 589 size: (64, 64)
# Image 590 size: (64, 64)
# Image 591 size: (64, 64)
# Image 592 size: (64, 64)
# Image 593 size: (64, 64)
# Image 594 size: (64, 64)
# Image 595 size: (64, 64)
# Image 596 size: (64, 64)
# Image 597 size: (64, 64)
# Image 598 size: (64, 64)
# Image 599 size: (64, 64)
# Image 600 size: (64, 64)
# Image 601 size: (64, 64)
# Image 602 size: (64, 64)
# Image 603 size: (64, 64)
# Image 604 size: (64, 64)
# Image 605 size: (64, 64)
# Image 606 size: (64, 64)
# Image 607 size: (64, 64)
# Image 608 size: (64, 64)
# Image 609 size: (64, 64)
# Image 610 size: (64, 64)
# Image 611 size: (64, 64)
# Image 612 size: (64, 64)
# Image 613 size: (64, 64)
# Image 614 size: (64, 64)
# Image 615 size: (64, 64)
# Image 616 size: (64, 64)
# Image 617 size: (64, 64)
# Image 618 size: (64, 64)
# Image 619 size: (64, 64)
# Image 620 size: (64, 64)
# Image 621 size: (64, 64)
# Image 622 size: (64, 64)
# Image 623 size: (64, 64)
# Image 624 size: (64, 64)
# Image 625 size: (64, 64)
# Image 626 size: (64, 64)
# Image 627 size: (64, 64)
# Image 628 size: (64, 64)
# Image 629 size: (64, 64)
# Image 630 size: (64, 64)
# Image 631 size: (64, 64)
# Image 632 size: (64, 64)
# Image 633 size: (64, 64)
# Image 634 size: (64, 64)
# Image 635 size: (64, 64)
# Image 636 size: (64, 64)
# Image 637 size: (64, 64)
# Image 638 size: (64, 64)
# Image 639 size: (64, 64)
# Image 640 size: (64, 64)
# Image 641 size: (64, 64)
# Image 642 size: (64, 64)
# Image 643 size: (64, 64)
# Image 644 size: (64, 64)
# Image 645 size: (64, 64)
# Image 646 size: (64, 64)
# Image 647 size: (64, 64)
# Image 648 size: (64, 64)
# Image 649 size: (64, 64)
# Image 650 size: (64, 64)
# Image 651 size: (64, 64)
# Image 652 size: (64, 64)
# Image 653 size: (64, 64)
# Image 654 size: (64, 64)
# Image 655 size: (64, 64)
# Image 656 size: (64, 64)
# Image 657 size: (64, 64)
# Image 658 size: (64, 64)
# Image 659 size: (64, 64)
# Image 660 size: (64, 64)
# Image 661 size: (64, 64)
# Image 662 size: (64, 64)
# Image 663 size: (64, 64)
# Image 664 size: (64, 64)
# Image 665 size: (64, 64)
# Image 666 size: (64, 64)
# Image 667 size: (64, 64)
# Image 668 size: (64, 64)
# Image 669 size: (64, 64)
# Image 670 size: (64, 64)
# Image 671 size: (64, 64)
# Image 672 size: (64, 64)
# Image 673 size: (64, 64)
# Image 674 size: (64, 64)
# Image 675 size: (64, 64)
# Image 676 size: (64, 64)
# Image 677 size: (64, 64)
# Image 678 size: (64, 64)
# Image 679 size: (64, 64)
# Image 680 size: (64, 64)
# Image 681 size: (64, 64)
# Image 682 size: (64, 64)
# Image 683 size: (64, 64)
# Image 684 size: (64, 64)
# Image 685 size: (64, 64)
# Image 686 size: (64, 64)
# Image 687 size: (64, 64)
# Image 688 size: (64, 64)
# Image 689 size: (64, 64)
# Image 690 size: (64, 64)
# Image 691 size: (64, 64)
# Image 692 size: (64, 64)
# Image 693 size: (64, 64)
# Image 694 size: (64, 64)
# Image 695 size: (64, 64)
# Image 696 size: (64, 64)
# Image 697 size: (64, 64)
# Image 698 size: (64, 64)
# Image 699 size: (64, 64)
# Image 700 size: (64, 64)
# Image 701 size: (64, 64)
# Image 702 size: (64, 64)
# Image 703 size: (64, 64)
# Image 704 size: (64, 64)
# Image 705 size: (64, 64)
# Image 706 size: (64, 64)
# Image 707 size: (64, 64)
# Image 708 size: (64, 64)
# Image 709 size: (64, 64)
# Image 710 size: (64, 64)
# Image 711 size: (64, 64)
# Image 712 size: (64, 64)
# Image 713 size: (64, 64)
# Image 714 size: (64, 64)
# Image 715 size: (64, 64)
# Image 716 size: (64, 64)
# Image 717 size: (64, 64)
# Image 718 size: (64, 64)
# Image 719 size: (64, 64)
# Image 720 size: (64, 64)
# Image 721 size: (64, 64)
# Image 722 size: (64, 64)
# Image 723 size: (64, 64)
# Image 724 size: (64, 64)
# Image 725 size: (64, 64)
# Image 726 size: (64, 64)
# Image 727 size: (64, 64)
# Image 728 size: (64, 64)
# Image 729 size: (64, 64)
# Image 730 size: (64, 64)
# Image 731 size: (64, 64)
# Image 732 size: (64, 64)
# Image 733 size: (64, 64)
# Image 734 size: (64, 64)
# Image 735 size: (64, 64)
# Image 736 size: (64, 64)
# Image 737 size: (64, 64)
# Image 738 size: (64, 64)
# Image 739 size: (64, 64)
# Image 740 size: (64, 64)
# Image 741 size: (64, 64)
# Image 742 size: (64, 64)
# Image 743 size: (64, 64)
# Image 744 size: (64, 64)
# Image 745 size: (64, 64)
# Image 746 size: (64, 64)
# Image 747 size: (64, 64)
# Image 748 size: (64, 64)
# Image 749 size: (64, 64)
# Image 750 size: (64, 64)
# Image 751 size: (64, 64)
# Image 752 size: (64, 64)
# Image 753 size: (64, 64)
# Image 754 size: (64, 64)
# Image 755 size: (64, 64)
# Image 756 size: (64, 64)
# Image 757 size: (64, 64)
# Image 758 size: (64, 64)
# Image 759 size: (64, 64)
# Image 760 size: (64, 64)
# Image 761 size: (64, 64)
# Image 762 size: (64, 64)
# Image 763 size: (64, 64)
# Image 764 size: (64, 64)
# Image 765 size: (64, 64)
# Image 766 size: (64, 64)
# Image 767 size: (64, 64)
# Image 768 size: (64, 64)
# Image 769 size: (64, 64)
# Image 770 size: (64, 64)
# Image 771 size: (64, 64)
# Image 772 size: (64, 64)
# Image 773 size: (64, 64)
# Image 774 size: (64, 64)
# Image 775 size: (64, 64)
# Image 776 size: (64, 64)
# Image 777 size: (64, 64)
# Image 778 size: (64, 64)
# Image 779 size: (64, 64)
# Image 780 size: (64, 64)
# Image 781 size: (64, 64)
# Image 782 size: (64, 64)
# Image 783 size: (64, 64)
# Image 784 size: (64, 64)
# Image 785 size: (64, 64)
# Image 786 size: (64, 64)
# Image 787 size: (64, 64)
# Image 788 size: (64, 64)
# Image 789 size: (64, 64)
# Image 790 size: (64, 64)
# Image 791 size: (64, 64)
# Image 792 size: (64, 64)
# Image 793 size: (64, 64)
# Image 794 size: (64, 64)
# Image 795 size: (64, 64)
# Image 796 size: (64, 64)
# Image 797 size: (64, 64)
# Image 798 size: (64, 64)
# Image 799 size: (64, 64)
# Image 800 size: (64, 64)
# Image 801 size: (64, 64)
# Image 802 size: (64, 64)
# Image 803 size: (64, 64)
# Image 804 size: (64, 64)
# Image 805 size: (64, 64)
# Image 806 size: (64, 64)
# Image 807 size: (64, 64)
# Image 808 size: (64, 64)
# Image 809 size: (64, 64)
# Image 810 size: (64, 64)
# Image 811 size: (64, 64)
# Image 812 size: (64, 64)
# Image 813 size: (64, 64)
# Image 814 size: (64, 64)
# Image 815 size: (64, 64)
# Image 816 size: (64, 64)
# Image 817 size: (64, 64)
# Image 818 size: (64, 64)
# Image 819 size: (64, 64)
# Image 820 size: (64, 64)
# Image 821 size: (64, 64)
# Image 822 size: (64, 64)
# Image 823 size: (64, 64)
# Image 824 size: (64, 64)
# Image 825 size: (64, 64)
# Image 826 size: (64, 64)
# Image 827 size: (64, 64)
# Image 828 size: (64, 64)
# Image 829 size: (64, 64)
# Image 830 size: (64, 64)
# Image 831 size: (64, 64)
# Image 832 size: (64, 64)
# Image 833 size: (64, 64)
# Image 834 size: (64, 64)
# Image 835 size: (64, 64)
# Image 836 size: (64, 64)
# Image 837 size: (64, 64)
# Image 838 size: (64, 64)
# Image 839 size: (64, 64)
# Image 840 size: (64, 64)
# Image 841 size: (64, 64)
# Image 842 size: (64, 64)
# Image 843 size: (64, 64)
# Image 844 size: (64, 64)
# Image 845 size: (64, 64)
# Image 846 size: (64, 64)
# Image 847 size: (64, 64)
# Image 848 size: (64, 64)
# Image 849 size: (64, 64)
# Image 850 size: (64, 64)
# Image 851 size: (64, 64)
# Image 852 size: (64, 64)
# Image 853 size: (64, 64)
# Image 854 size: (64, 64)
# Image 855 size: (64, 64)
# Image 856 size: (64, 64)
# Image 857 size: (64, 64)
# Image 858 size: (64, 64)
# Image 859 size: (64, 64)
# Image 860 size: (64, 64)
# Image 861 size: (64, 64)
# Image 862 size: (64, 64)
# Image 863 size: (64, 64)
# Image 864 size: (64, 64)
# Image 865 size: (64, 64)
# Image 866 size: (64, 64)
# Image 867 size: (64, 64)
# Image 868 size: (64, 64)
# Image 869 size: (64, 64)
# Image 870 size: (64, 64)
# Image 871 size: (64, 64)
# Image 872 size: (64, 64)
# Image 873 size: (64, 64)
# Image 874 size: (64, 64)
# Image 875 size: (64, 64)
# Image 876 size: (64, 64)
# Image 877 size: (64, 64)
# Image 878 size: (64, 64)
# Image 879 size: (64, 64)
# Image 880 size: (64, 64)
# Image 881 size: (64, 64)
# Image 882 size: (64, 64)
# Image 883 size: (64, 64)
# Image 884 size: (64, 64)
# Image 885 size: (64, 64)
# Image 886 size: (64, 64)
# Image 887 size: (64, 64)
# Image 888 size: (64, 64)
# Image 889 size: (64, 64)
# Image 890 size: (64, 64)
# Image 891 size: (64, 64)
# Image 892 size: (64, 64)
# Image 893 size: (64, 64)
# Image 894 size: (64, 64)
# Image 895 size: (64, 64)
# Image 896 size: (64, 64)
# Image 897 size: (64, 64)
# Image 898 size: (64, 64)
# Image 899 size: (64, 64)
# Image 900 size: (64, 64)
# Image 901 size: (64, 64)
# Image 902 size: (64, 64)
# Image 903 size: (64, 64)
# Image 904 size: (64, 64)
# Image 905 size: (64, 64)
# Image 906 size: (64, 64)
# Image 907 size: (64, 64)
# Image 908 size: (64, 64)
# Image 909 size: (64, 64)
# Image 910 size: (64, 64)
# Image 911 size: (64, 64)
# Image 912 size: (64, 64)
# Image 913 size: (64, 64)
# Image 914 size: (64, 64)
# Image 915 size: (64, 64)
# Image 916 size: (64, 64)
# Image 917 size: (64, 64)
# Image 918 size: (64, 64)
# Image 919 size: (64, 64)
# Image 920 size: (64, 64)
# Image 921 size: (64, 64)
# Image 922 size: (64, 64)
# Image 923 size: (64, 64)
# Image 924 size: (64, 64)
# Image 925 size: (64, 64)
# Image 926 size: (64, 64)
# Image 927 size: (64, 64)
# Image 928 size: (64, 64)
# Image 929 size: (64, 64)
# Image 930 size: (64, 64)
# Image 931 size: (64, 64)
# Image 932 size: (64, 64)
# Image 933 size: (64, 64)
# Image 934 size: (64, 64)
# Image 935 size: (64, 64)
# Image 936 size: (64, 64)
# Image 937 size: (64, 64)
# Image 938 size: (64, 64)
# Image 939 size: (64, 64)
# Image 940 size: (64, 64)
# Image 941 size: (64, 64)
# Image 942 size: (64, 64)
# Image 943 size: (64, 64)
# Image 944 size: (64, 64)
# Image 945 size: (64, 64)
# Image 946 size: (64, 64)
# Image 947 size: (64, 64)
# Image 948 size: (64, 64)
# Image 949 size: (64, 64)
# Image 950 size: (64, 64)
# Image 951 size: (64, 64)
# Image 952 size: (64, 64)
# Image 953 size: (64, 64)
# Image 954 size: (64, 64)
# Image 955 size: (64, 64)
# Image 956 size: (64, 64)
# Image 957 size: (64, 64)
# Image 958 size: (64, 64)
# Image 959 size: (64, 64)
# Image 960 size: (64, 64)
# Image 961 size: (64, 64)
# Image 962 size: (64, 64)
# Image 963 size: (64, 64)
# Image 964 size: (64, 64)
# Image 965 size: (64, 64)
# Image 966 size: (64, 64)
# Image 967 size: (64, 64)
# Image 968 size: (64, 64)
# Image 969 size: (64, 64)
# Image 970 size: (64, 64)
# Image 971 size: (64, 64)
# Image 972 size: (64, 64)
# Image 973 size: (64, 64)
# Image 974 size: (64, 64)
# Image 975 size: (64, 64)
# Image 976 size: (64, 64)
# Image 977 size: (64, 64)
# Image 978 size: (64, 64)
# Image 979 size: (64, 64)
# Image 980 size: (64, 64)
# Image 981 size: (64, 64)
# Image 982 size: (64, 64)
# Image 983 size: (64, 64)
# Image 984 size: (64, 64)
# Image 985 size: (64, 64)
# Image 986 size: (64, 64)
# Image 987 size: (64, 64)
# Image 988 size: (64, 64)
# Image 989 size: (64, 64)
# Image 990 size: (64, 64)
# Image 991 size: (64, 64)
# Image 992 size: (64, 64)
# Image 993 size: (64, 64)
# Image 994 size: (64, 64)
# Image 995 size: (64, 64)
# Image 996 size: (64, 64)
# Image 997 size: (64, 64)
# Image 998 size: (64, 64)
# Image 999 size: (64, 64)
# Image 1000 size: (64, 64)
# Image 1001 size: (64, 64)
# Image 1002 size: (64, 64)
# Image 1003 size: (64, 64)
# Image 1004 size: (64, 64)
# Image 1005 size: (64, 64)
# Image 1006 size: (64, 64)
# Image 1007 size: (64, 64)
# Image 1008 size: (64, 64)
# Image 1009 size: (64, 64)
# Image 1010 size: (64, 64)
# Image 1011 size: (64, 64)
# Image 1012 size: (64, 64)
# Image 1013 size: (64, 64)
# Image 1014 size: (64, 64)
# Image 1015 size: (64, 64)
# Image 1016 size: (64, 64)
# Image 1017 size: (64, 64)
# Image 1018 size: (64, 64)
# Image 1019 size: (64, 64)
# Image 1020 size: (64, 64)
# Image 1021 size: (64, 64)
# Image 1022 size: (64, 64)
# Image 1023 size: (64, 64)
# Image 1024 size: (64, 64)
# Image 1025 size: (64, 64)
# Image 1026 size: (64, 64)
# Image 1027 size: (64, 64)
# Image 1028 size: (64, 64)
# Image 1029 size: (64, 64)
# Image 1030 size: (64, 64)
# Image 1031 size: (64, 64)
# Image 1032 size: (64, 64)
# Image 1033 size: (64, 64)
# Image 1034 size: (64, 64)
# Image 1035 size: (64, 64)
# Image 1036 size: (64, 64)
# Image 1037 size: (64, 64)
# Image 1038 size: (64, 64)
# Image 1039 size: (64, 64)
# Image 1040 size: (64, 64)
# Image 1041 size: (64, 64)
# Image 1042 size: (64, 64)
# Image 1043 size: (64, 64)
# Image 1044 size: (64, 64)
# Image 1045 size: (64, 64)
# Image 1046 size: (64, 64)
# Image 1047 size: (64, 64)
# Image 1048 size: (64, 64)
# Image 1049 size: (64, 64)
# Image 1050 size: (64, 64)
# Image 1051 size: (64, 64)
# Image 1052 size: (64, 64)
# Image 1053 size: (64, 64)
# Image 1054 size: (64, 64)
# Image 1055 size: (64, 64)
# Image 1056 size: (64, 64)
# Image 1057 size: (64, 64)
# Image 1058 size: (64, 64)
# Image 1059 size: (64, 64)
# Image 1060 size: (64, 64)
# Image 1061 size: (64, 64)
# Image 1062 size: (64, 64)
# Image 1063 size: (64, 64)
# Image 1064 size: (64, 64)
# Image 1065 size: (64, 64)
# Image 1066 size: (64, 64)
# Image 1067 size: (64, 64)
# Image 1068 size: (64, 64)
# Image 1069 size: (64, 64)
# Image 1070 size: (64, 64)
# Image 1071 size: (64, 64)
# Image 1072 size: (64, 64)
# Image 1073 size: (64, 64)
# Image 1074 size: (64, 64)
# Image 1075 size: (64, 64)
# Image 1076 size: (64, 64)
# Image 1077 size: (64, 64)
# Image 1078 size: (64, 64)
# Image 1079 size: (64, 64)
# Image 1080 size: (64, 64)
# Image 1081 size: (64, 64)
# Image 1082 size: (64, 64)
# Image 1083 size: (64, 64)
# Image 1084 size: (64, 64)
# Image 1085 size: (64, 64)
# Image 1086 size: (64, 64)
# Image 1087 size: (64, 64)
# Image 1088 size: (64, 64)
# Image 1089 size: (64, 64)
# Image 1090 size: (64, 64)
# Image 1091 size: (64, 64)
# Image 1092 size: (64, 64)
# Image 1093 size: (64, 64)
# Image 1094 size: (64, 64)
# Image 1095 size: (64, 64)
# Image 1096 size: (64, 64)
# Image 1097 size: (64, 64)
# Image 1098 size: (64, 64)
# Image 1099 size: (64, 64)
# Image 1100 size: (64, 64)
# Image 1101 size: (64, 64)
# Image 1102 size: (64, 64)
# Image 1103 size: (64, 64)
# Image 1104 size: (64, 64)
# Image 1105 size: (64, 64)
# Image 1106 size: (64, 64)
# Image 1107 size: (64, 64)
# Image 1108 size: (64, 64)
# Image 1109 size: (64, 64)
# Image 1110 size: (64, 64)
# Image 1111 size: (64, 64)
# Image 1112 size: (64, 64)
# Image 1113 size: (64, 64)
# Image 1114 size: (64, 64)
# Image 1115 size: (64, 64)
# Image 1116 size: (64, 64)
# Image 1117 size: (64, 64)
# Image 1118 size: (64, 64)
# Image 1119 size: (64, 64)
# Image 1120 size: (64, 64)
# Image 1121 size: (64, 64)
# Image 1122 size: (64, 64)
# Image 1123 size: (64, 64)
# Image 1124 size: (64, 64)
# Image 1125 size: (64, 64)
# Image 1126 size: (64, 64)
# Image 1127 size: (64, 64)
# Image 1128 size: (64, 64)
# Image 1129 size: (64, 64)
# Image 1130 size: (64, 64)
# Image 1131 size: (64, 64)
# Image 1132 size: (64, 64)
# Image 1133 size: (64, 64)
# Image 1134 size: (64, 64)
# Image 1135 size: (64, 64)
# Image 1136 size: (64, 64)
# Image 1137 size: (64, 64)
# Image 1138 size: (64, 64)
# Image 1139 size: (64, 64)
# Image 1140 size: (64, 64)
# Image 1141 size: (64, 64)
# Image 1142 size: (64, 64)
# Image 1143 size: (64, 64)
# Image 1144 size: (64, 64)
# Image 1145 size: (64, 64)
# Image 1146 size: (64, 64)
# Image 1147 size: (64, 64)
# Image 1148 size: (64, 64)
# Image 1149 size: (64, 64)
# Image 1150 size: (64, 64)
# Image 1151 size: (64, 64)
# Image 1152 size: (64, 64)
# Image 1153 size: (64, 64)
# Image 1154 size: (64, 64)
# Image 1155 size: (64, 64)
# Image 1156 size: (64, 64)
# Image 1157 size: (64, 64)
# Image 1158 size: (64, 64)
# Image 1159 size: (64, 64)
# Image 1160 size: (64, 64)
# Image 1161 size: (64, 64)
# Image 1162 size: (64, 64)
# Image 1163 size: (64, 64)
# Image 1164 size: (64, 64)
# Image 1165 size: (64, 64)
# Image 1166 size: (64, 64)
# Image 1167 size: (64, 64)
# Image 1168 size: (64, 64)
# Image 1169 size: (64, 64)
# Image 1170 size: (64, 64)
# Image 1171 size: (64, 64)
# Image 1172 size: (64, 64)
# Image 1173 size: (64, 64)
# Image 1174 size: (64, 64)
# Image 1175 size: (64, 64)
# Image 1176 size: (64, 64)
# Image 1177 size: (64, 64)
# Image 1178 size: (64, 64)
# Image 1179 size: (64, 64)
# Image 1180 size: (64, 64)
# Image 1181 size: (64, 64)
# Image 1182 size: (64, 64)
# Image 1183 size: (64, 64)
# Image 1184 size: (64, 64)
# Image 1185 size: (64, 64)
# Image 1186 size: (64, 64)
# Image 1187 size: (64, 64)
# Image 1188 size: (64, 64)
# Image 1189 size: (64, 64)
# Image 1190 size: (64, 64)
# Image 1191 size: (64, 64)
# Image 1192 size: (64, 64)
# Image 1193 size: (64, 64)
# Image 1194 size: (64, 64)
# Image 1195 size: (64, 64)
# Image 1196 size: (64, 64)
# Image 1197 size: (64, 64)
# Image 1198 size: (64, 64)
# Image 1199 size: (64, 64)
# Image 1200 size: (64, 64)
# Image 1201 size: (64, 64)
# Image 1202 size: (64, 64)
# Image 1203 size: (64, 64)
# Image 1204 size: (64, 64)
# Image 1205 size: (64, 64)
# Image 1206 size: (64, 64)
# Image 1207 size: (64, 64)
# Image 1208 size: (64, 64)
# Image 1209 size: (64, 64)
# Image 1210 size: (64, 64)
# Image 1211 size: (64, 64)
# Image 1212 size: (64, 64)
# Image 1213 size: (64, 64)
# Image 1214 size: (64, 64)
# Image 1215 size: (64, 64)
# Image 1216 size: (64, 64)
# Image 1217 size: (64, 64)
# Image 1218 size: (64, 64)
# Image 1219 size: (64, 64)
# Image 1220 size: (64, 64)
# Image 1221 size: (64, 64)
# Image 1222 size: (64, 64)
# Image 1223 size: (64, 64)
# Image 1224 size: (64, 64)
# Image 1225 size: (64, 64)
# Image 1226 size: (64, 64)
# Image 1227 size: (64, 64)
# Image 1228 size: (64, 64)
# Image 1229 size: (64, 64)
# Image 1230 size: (64, 64)
# Image 1231 size: (64, 64)
# Image 1232 size: (64, 64)
# Image 1233 size: (64, 64)
# Image 1234 size: (64, 64)
# Image 1235 size: (64, 64)
# Image 1236 size: (64, 64)
# Image 1237 size: (64, 64)
# Image 1238 size: (64, 64)
# Image 1239 size: (64, 64)
# Image 1240 size: (64, 64)
# Image 1241 size: (64, 64)
# Image 1242 size: (64, 64)
# Image 1243 size: (64, 64)
# Image 1244 size: (64, 64)
# Image 1245 size: (64, 64)
# Image 1246 size: (64, 64)
# Image 1247 size: (64, 64)
# Image 1248 size: (64, 64)
# Image 1249 size: (64, 64)
# Image 1250 size: (64, 64)
# Image 1251 size: (64, 64)
# Image 1252 size: (64, 64)
# Image 1253 size: (64, 64)
# Image 1254 size: (64, 64)
# Image 1255 size: (64, 64)
# Image 1256 size: (64, 64)
# Image 1257 size: (64, 64)
# Image 1258 size: (64, 64)
# Image 1259 size: (64, 64)
# Image 1260 size: (64, 64)
# Image 1261 size: (64, 64)
# Image 1262 size: (64, 64)
# Image 1263 size: (64, 64)
# Image 1264 size: (64, 64)
# Image 1265 size: (64, 64)
# Image 1266 size: (64, 64)
# Image 1267 size: (64, 64)
# Image 1268 size: (64, 64)
# Image 1269 size: (64, 64)
# Image 1270 size: (64, 64)
# Image 1271 size: (64, 64)
# Image 1272 size: (64, 64)
# Image 1273 size: (64, 64)
# Image 1274 size: (64, 64)
# Image 1275 size: (64, 64)
# Image 1276 size: (64, 64)
# Image 1277 size: (64, 64)
# Image 1278 size: (64, 64)
# Image 1279 size: (64, 64)
# Image 1280 size: (64, 64)
# Image 1281 size: (64, 64)
# Image 1282 size: (64, 64)
# Image 1283 size: (64, 64)
# Image 1284 size: (64, 64)
# Image 1285 size: (64, 64)
# Image 1286 size: (64, 64)
# Image 1287 size: (64, 64)
# Image 1288 size: (64, 64)
# Image 1289 size: (64, 64)
# Image 1290 size: (64, 64)
# Image 1291 size: (64, 64)
# Image 1292 size: (64, 64)
# Image 1293 size: (64, 64)
# Image 1294 size: (64, 64)
# Image 1295 size: (64, 64)
# Image 1296 size: (64, 64)
# Image 1297 size: (64, 64)
# Image 1298 size: (64, 64)
# Image 1299 size: (64, 64)
# Image 1300 size: (64, 64)
# Image 1301 size: (64, 64)
# Image 1302 size: (64, 64)
# Image 1303 size: (64, 64)
# Image 1304 size: (64, 64)
# Image 1305 size: (64, 64)
# Image 1306 size: (64, 64)
# Image 1307 size: (64, 64)
# Image 1308 size: (64, 64)
# Image 1309 size: (64, 64)
# Image 1310 size: (64, 64)
# Image 1311 size: (64, 64)
# Image 1312 size: (64, 64)
# Image 1313 size: (64, 64)
# Image 1314 size: (64, 64)
# Image 1315 size: (64, 64)
# Image 1316 size: (64, 64)
# Image 1317 size: (64, 64)
# Image 1318 size: (64, 64)
# Image 1319 size: (64, 64)
# Image 1320 size: (64, 64)
# Image 1321 size: (64, 64)
# Image 1322 size: (64, 64)
# Image 1323 size: (64, 64)
# Image 1324 size: (64, 64)
# Image 1325 size: (64, 64)
# Image 1326 size: (64, 64)
# Image 1327 size: (64, 64)
# Image 1328 size: (64, 64)
# Image 1329 size: (64, 64)
# Image 1330 size: (64, 64)
# Image 1331 size: (64, 64)
# Image 1332 size: (64, 64)
# Image 1333 size: (64, 64)
# Image 1334 size: (64, 64)
# Image 1335 size: (64, 64)
# Image 1336 size: (64, 64)
# Image 1337 size: (64, 64)
# Image 1338 size: (64, 64)
# Image 1339 size: (64, 64)
# Image 1340 size: (64, 64)
# Image 1341 size: (64, 64)
# Image 1342 size: (64, 64)
# Image 1343 size: (64, 64)
# Image 1344 size: (64, 64)
# Image 1345 size: (64, 64)
# Image 1346 size: (64, 64)
# Image 1347 size: (64, 64)
# Image 1348 size: (64, 64)
# Image 1349 size: (64, 64)
# Image 1350 size: (64, 64)
# Image 1351 size: (64, 64)
# Image 1352 size: (64, 64)
# Image 1353 size: (64, 64)
# Image 1354 size: (64, 64)
# Image 1355 size: (64, 64)
# Image 1356 size: (64, 64)
# Image 1357 size: (64, 64)
# Image 1358 size: (64, 64)
# Image 1359 size: (64, 64)
# Image 1360 size: (64, 64)
# Image 1361 size: (64, 64)
# Image 1362 size: (64, 64)
# Image 1363 size: (64, 64)
# Image 1364 size: (64, 64)
# Image 1365 size: (64, 64)
# Image 1366 size: (64, 64)
# Image 1367 size: (64, 64)
# Image 1368 size: (64, 64)
# Image 1369 size: (64, 64)
# Image 1370 size: (64, 64)
# Image 1371 size: (64, 64)
# Image 1372 size: (64, 64)
# Image 1373 size: (64, 64)
# Image 1374 size: (64, 64)
# Image 1375 size: (64, 64)
# Image 1376 size: (64, 64)
# Image 1377 size: (64, 64)
# Image 1378 size: (64, 64)
# Image 1379 size: (64, 64)
# Image 1380 size: (64, 64)
# Image 1381 size: (64, 64)
# Image 1382 size: (64, 64)
# Image 1383 size: (64, 64)
# Image 1384 size: (64, 64)
# Image 1385 size: (64, 64)
# Image 1386 size: (64, 64)
# Image 1387 size: (64, 64)
# Image 1388 size: (64, 64)
# Image 1389 size: (64, 64)
# Image 1390 size: (64, 64)
# Image 1391 size: (64, 64)
# Image 1392 size: (64, 64)
# Image 1393 size: (64, 64)
# Image 1394 size: (64, 64)
# Image 1395 size: (64, 64)
# Image 1396 size: (64, 64)
# Image 1397 size: (64, 64)
# Image 1398 size: (64, 64)
# Image 1399 size: (64, 64)
# Image 1400 size: (64, 64)
# Image 1401 size: (64, 64)
# Image 1402 size: (64, 64)
# Image 1403 size: (64, 64)
# Image 1404 size: (64, 64)
# Image 1405 size: (64, 64)
# Image 1406 size: (64, 64)
# Image 1407 size: (64, 64)
# Image 1408 size: (64, 64)
# Image 1409 size: (64, 64)
# Image 1410 size: (64, 64)
# Image 1411 size: (64, 64)
# Image 1412 size: (64, 64)
# Image 1413 size: (64, 64)
# Image 1414 size: (64, 64)
# Image 1415 size: (64, 64)
# Image 1416 size: (64, 64)
# Image 1417 size: (64, 64)
# Image 1418 size: (64, 64)
# Image 1419 size: (64, 64)
# Image 1420 size: (64, 64)
# Image 1421 size: (64, 64)
# Image 1422 size: (64, 64)
# Image 1423 size: (64, 64)
# Image 1424 size: (64, 64)
# Image 1425 size: (64, 64)
# Image 1426 size: (64, 64)
# Image 1427 size: (64, 64)
# Image 1428 size: (64, 64)
# Image 1429 size: (64, 64)
# Image 1430 size: (64, 64)
# Image 1431 size: (64, 64)
# Image 1432 size: (64, 64)
# Image 1433 size: (64, 64)
# Image 1434 size: (64, 64)
# Image 1435 size: (64, 64)
# Image 1436 size: (64, 64)
# Image 1437 size: (64, 64)
# Image 1438 size: (64, 64)
# Image 1439 size: (64, 64)
# Image 1440 size: (64, 64)
# Image 1441 size: (64, 64)
# Image 1442 size: (64, 64)
# Image 1443 size: (64, 64)
# Image 1444 size: (64, 64)
# Image 1445 size: (64, 64)
# Image 1446 size: (64, 64)
# Image 1447 size: (64, 64)
# Image 1448 size: (64, 64)
# Image 1449 size: (64, 64)
# Image 1450 size: (64, 64)
# Image 1451 size: (64, 64)
# Image 1452 size: (64, 64)
# Image 1453 size: (64, 64)
# Image 1454 size: (64, 64)
# Image 1455 size: (64, 64)
# Image 1456 size: (64, 64)
# Image 1457 size: (64, 64)
# Image 1458 size: (64, 64)
# Image 1459 size: (64, 64)
# Image 1460 size: (64, 64)
# Image 1461 size: (64, 64)
# Image 1462 size: (64, 64)
# Image 1463 size: (64, 64)
# Image 1464 size: (64, 64)
# Image 1465 size: (64, 64)
# Image 1466 size: (64, 64)
# Image 1467 size: (64, 64)
# Image 1468 size: (64, 64)
# Image 1469 size: (64, 64)
# Image 1470 size: (64, 64)
# Image 1471 size: (64, 64)
# Image 1472 size: (64, 64)
# Image 1473 size: (64, 64)
# Image 1474 size: (64, 64)
# Image 1475 size: (64, 64)
# Image 1476 size: (64, 64)
# Image 1477 size: (64, 64)
# Image 1478 size: (64, 64)
# Image 1479 size: (64, 64)
# Image 1480 size: (64, 64)
# Image 1481 size: (64, 64)
# Image 1482 size: (64, 64)
# Image 1483 size: (64, 64)
# Image 1484 size: (64, 64)
# Image 1485 size: (64, 64)
# Image 1486 size: (64, 64)
# Image 1487 size: (64, 64)
# Image 1488 size: (64, 64)
# Image 1489 size: (64, 64)
# Image 1490 size: (64, 64)
# Image 1491 size: (64, 64)
# Image 1492 size: (64, 64)
# Image 1493 size: (64, 64)
# Image 1494 size: (64, 64)
# Image 1495 size: (64, 64)
# Image 1496 size: (64, 64)
# Image 1497 size: (64, 64)
# Image 1498 size: (64, 64)
# Image 1499 size: (64, 64)
# Image 1500 size: (64, 64)
# Image 1501 size: (64, 64)
# Image 1502 size: (64, 64)
# Image 1503 size: (64, 64)
# Image 1504 size: (64, 64)
# Image 1505 size: (64, 64)
# Image 1506 size: (64, 64)
# Image 1507 size: (64, 64)
# Image 1508 size: (64, 64)
# Image 1509 size: (64, 64)
# Image 1510 size: (64, 64)
# Image 1511 size: (64, 64)
# Image 1512 size: (64, 64)
# Image 1513 size: (64, 64)
# Image 1514 size: (64, 64)
# Image 1515 size: (64, 64)
# Image 1516 size: (64, 64)
# Image 1517 size: (64, 64)
# Image 1518 size: (64, 64)
# Image 1519 size: (64, 64)
# Image 1520 size: (64, 64)
# Image 1521 size: (64, 64)
# Image 1522 size: (64, 64)
# Image 1523 size: (64, 64)
# Image 1524 size: (64, 64)
# Image 1525 size: (64, 64)
# Image 1526 size: (64, 64)
# Image 1527 size: (64, 64)
# Image 1528 size: (64, 64)
# Image 1529 size: (64, 64)
# Image 1530 size: (64, 64)
# Image 1531 size: (64, 64)
# Image 1532 size: (64, 64)
# Image 1533 size: (64, 64)
# Image 1534 size: (64, 64)
# Image 1535 size: (64, 64)
# Image 1536 size: (64, 64)
# Image 1537 size: (64, 64)
# Image 1538 size: (64, 64)
# Image 1539 size: (64, 64)
# Image 1540 size: (64, 64)
# Image 1541 size: (64, 64)
# Image 1542 size: (64, 64)
# Image 1543 size: (64, 64)
# Image 1544 size: (64, 64)
# Image 1545 size: (64, 64)
# Image 1546 size: (64, 64)
# Image 1547 size: (64, 64)
# Image 1548 size: (64, 64)
# Image 1549 size: (64, 64)
# Image 1550 size: (64, 64)
# Image 1551 size: (64, 64)
# Image 1552 size: (64, 64)
# Image 1553 size: (64, 64)
# Image 1554 size: (64, 64)
# Image 1555 size: (64, 64)
# Image 1556 size: (64, 64)
# Image 1557 size: (64, 64)
# Image 1558 size: (64, 64)
# Image 1559 size: (64, 64)
# Image 1560 size: (64, 64)
# Image 1561 size: (64, 64)
# Image 1562 size: (64, 64)
# Image 1563 size: (64, 64)
# Image 1564 size: (64, 64)
# Image 1565 size: (64, 64)
# Image 1566 size: (64, 64)
# Image 1567 size: (64, 64)
# Image 1568 size: (64, 64)
# Image 1569 size: (64, 64)
# Image 1570 size: (64, 64)
# Image 1571 size: (64, 64)
# Image 1572 size: (64, 64)
# Image 1573 size: (64, 64)
# Image 1574 size: (64, 64)
# Image 1575 size: (64, 64)
# Image 1576 size: (64, 64)
# Image 1577 size: (64, 64)
# Image 1578 size: (64, 64)
# Image 1579 size: (64, 64)
# Image 1580 size: (64, 64)
# Image 1581 size: (64, 64)
# Image 1582 size: (64, 64)
# Image 1583 size: (64, 64)
# Image 1584 size: (64, 64)
# Image 1585 size: (64, 64)
# Image 1586 size: (64, 64)
# Image 1587 size: (64, 64)
# Image 1588 size: (64, 64)
# Image 1589 size: (64, 64)
# Image 1590 size: (64, 64)
# Image 1591 size: (64, 64)
# Image 1592 size: (64, 64)
# Image 1593 size: (64, 64)
# Image 1594 size: (64, 64)
# Image 1595 size: (64, 64)
# Image 1596 size: (64, 64)
# Image 1597 size: (64, 64)
# Image 1598 size: (64, 64)
# Image 1599 size: (64, 64)
# Image 1600 size: (64, 64)
# Image 1601 size: (64, 64)
# Image 1602 size: (64, 64)
# Image 1603 size: (64, 64)
# Image 1604 size: (64, 64)
# Image 1605 size: (64, 64)
# Image 1606 size: (64, 64)
# Image 1607 size: (64, 64)
# Image 1608 size: (64, 64)
# Image 1609 size: (64, 64)
# Image 1610 size: (64, 64)
# Image 1611 size: (64, 64)
# Image 1612 size: (64, 64)
# Image 1613 size: (64, 64)
# Image 1614 size: (64, 64)
# Image 1615 size: (64, 64)
# Image 1616 size: (64, 64)
# Image 1617 size: (64, 64)
# Image 1618 size: (64, 64)
# Image 1619 size: (64, 64)
# Image 1620 size: (64, 64)
# Image 1621 size: (64, 64)
# Image 1622 size: (64, 64)
# Image 1623 size: (64, 64)
# Image 1624 size: (64, 64)
# Image 1625 size: (64, 64)
# Image 1626 size: (64, 64)
# Image 1627 size: (64, 64)
# Image 1628 size: (64, 64)
# Image 1629 size: (64, 64)
# Image 1630 size: (64, 64)
# Image 1631 size: (64, 64)
# Image 1632 size: (64, 64)
# Image 1633 size: (64, 64)
# Image 1634 size: (64, 64)
# Image 1635 size: (64, 64)
# Image 1636 size: (64, 64)
# Image 1637 size: (64, 64)
# Image 1638 size: (64, 64)
# Image 1639 size: (64, 64)
# Image 1640 size: (64, 64)
# Image 1641 size: (64, 64)
# Image 1642 size: (64, 64)
# Image 1643 size: (64, 64)
# Image 1644 size: (64, 64)
# Image 1645 size: (64, 64)
# Image 1646 size: (64, 64)
# Image 1647 size: (64, 64)
# Image 1648 size: (64, 64)
# Image 1649 size: (64, 64)
# Image 1650 size: (64, 64)
# Image 1651 size: (64, 64)
# Image 1652 size: (64, 64)
# Image 1653 size: (64, 64)
# Image 1654 size: (64, 64)
# Image 1655 size: (64, 64)
# Image 1656 size: (64, 64)
# Image 1657 size: (64, 64)
# Image 1658 size: (64, 64)
# Image 1659 size: (64, 64)
# Image 1660 size: (64, 64)
# Image 1661 size: (64, 64)
# Image 1662 size: (64, 64)
# Image 1663 size: (64, 64)
# Image 1664 size: (64, 64)
# Image 1665 size: (64, 64)
# Image 1666 size: (64, 64)
# Image 1667 size: (64, 64)
# Image 1668 size: (64, 64)
# Image 1669 size: (64, 64)
# Image 1670 size: (64, 64)
# Image 1671 size: (64, 64)
# Image 1672 size: (64, 64)
# Image 1673 size: (64, 64)
# Image 1674 size: (64, 64)
# Image 1675 size: (64, 64)
# Image 1676 size: (64, 64)
# Image 1677 size: (64, 64)
# Image 1678 size: (64, 64)
# Image 1679 size: (64, 64)
# Image 1680 size: (64, 64)
# Image 1681 size: (64, 64)
# Image 1682 size: (64, 64)
# Image 1683 size: (64, 64)
# Image 1684 size: (64, 64)
# Image 1685 size: (64, 64)
# Image 1686 size: (64, 64)
# Image 1687 size: (64, 64)
# Image 1688 size: (64, 64)
# Image 1689 size: (64, 64)
# Image 1690 size: (64, 64)
# Image 1691 size: (64, 64)
# Image 1692 size: (64, 64)
# Image 1693 size: (64, 64)
# Image 1694 size: (64, 64)
# Image 1695 size: (64, 64)
# Image 1696 size: (64, 64)
# Image 1697 size: (64, 64)
# Image 1698 size: (64, 64)
# Image 1699 size: (64, 64)
# Image 1700 size: (64, 64)
# Image 1701 size: (64, 64)
# Image 1702 size: (64, 64)
# Image 1703 size: (64, 64)
# Image 1704 size: (64, 64)
# Image 1705 size: (64, 64)
# Image 1706 size: (64, 64)
# Image 1707 size: (64, 64)
# Image 1708 size: (64, 64)
# Image 1709 size: (64, 64)

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import img_to_array


# Convert each image in X_train_augmented to a NumPy array
X_train_array = np.array([img_to_array(img) for img in X_train_augmented])  # Convert images to arrays

# %%
# Rescale the images
X_train_array = X_train_array / 255.0  # Rescale pixel values

# %%
# Map string labels to integers
label_mapping = {
    'cloudy': 0,
    'rainy': 1,
    'sunny': 2
}

# Convert string labels to integer labels
y_train_integer = [label_mapping[label] for label in y_train_augmented]

# One-hot encode the integer labels
y_train_array = to_categorical(y_train_integer, num_classes=len(label_mapping))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Create the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),  # Adjust input shape based on your images
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(len(label_mapping), activation='softmax')  # Number of classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_array, y_train_array, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model
loss, accuracy = model.evaluate(X_train_array, y_train_array)
print(f'Loss: {loss}, Accuracy: {accuracy}')
# Out:
# Epoch 1/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.5679 - loss: 0.9022 - val_accuracy: 0.7602 - val_loss: 0.7345
# Epoch 2/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8309 - loss: 0.4479 - val_accuracy: 0.8246 - val_loss: 0.4463
# Epoch 3/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8812 - loss: 0.3327 - val_accuracy: 0.6959 - val_loss: 0.7686
# Epoch 4/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9461 - loss: 0.1726 - val_accuracy: 0.8099 - val_loss: 0.5364
# Epoch 5/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9592 - loss: 0.1231 - val_accuracy: 0.7164 - val_loss: 0.7541
# Epoch 6/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9770 - loss: 0.0907 - val_accuracy: 0.8187 - val_loss: 0.4302
# Epoch 7/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9862 - loss: 0.0563 - val_accuracy: 0.8246 - val_loss: 0.5295
# Epoch 8/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.9877 - loss: 0.0545 - val_accuracy: 0.6550 - val_loss: 1.2039
# Epoch 9/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.9810 - loss: 0.0575 - val_accuracy: 0.7690 - val_loss: 0.8075
# Epoch 10/10
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9682 - loss: 0.0878 - val_accuracy: 0.6988 - val_loss: 1.0932
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9813 - loss: 0.0676
# Loss: 0.2596175968647003, Accuracy: 0.9269005656242371

# %% [markdown]
# You should be able to observe, from the performance data frame, that the basic CNN model that is trained on the augmented data performs better, in general, than the basic CNN model that you trained earlier.

# %% [markdown]
# ### Checklist
# - Converted the augmented input data into arrays
# - Scaled the augmented input data
# - Encoded the output data as integers
# - Performed one-hot encoding on output data
# - Retrained the simple CNN model on the augmented data
# - Created a data frame to analyze the performance of the model

# %% [markdown]
# # Stage 5 - Optimal Model
# In this stage, you will train your CNN model on the augmented data set and tune it for network structure and learning rate. You will do this by completing Task 12 - Tune the CNN Model.

# %% [markdown]
# ## Task 12 - Tune the CNN Model

# %% [markdown]
# ### Description
#
# In this task, you will train your CNN model on the augmented data set and tune it for network structure and learning rate.
#
# A grid search is not recommended here since we are working with sparse data. Instead, it is recommended to use simple loops and record the performance of the various model specifications. This also ensures that the same validation split and consequently the same validation data is used, so the model performance analyses are not biased, at least within the context of this assignment.
#
# Additionally note that you are required to restrict the complexity of your model. In general, more complex networks have a higher likelihood of overfitting. As part of this assignment, you are required to make sure that your networks contain no more than 500,000 trainable parameters.
#
# Note that you are required to report a performance data frame as you did earlier for each of the model specifications that you consider in this stage. You are free to report these as separate data frames or within a single data frame.
#
# For instance, if you consider 2 values for network configuration and 2 values for learning rate, then there are 4 unique model specifications. Consequently, you must train each of these model types multiple times (as specified earlier) and record the performance in each trial. You may, therefore, report 4 separate data frames (whose format you should be familiar with by this stage) or a single data frame that contains all the necessary information.

# %% [markdown]
# ### Requirements
# - Tune your model using loops and record the training and validation accuracies of each model over multiple runs.
# - Tune for at least two network configurations that are saved in the list *layers_config_list* (this includes the default configuration that you have been using up until this point).
# - Tune for at least two values of learning rate that are saved in the list *learning_rate_list* (this includes the default learning rate value of 0.001 that you have been using up until now).
# - Remember to tune for combinations of these hyperparameters (do not tune for them individually).
# - Ensure that the number of trainable parameters in your optimal model does not exceed 500,000.
# - Report your findings from the tuning process in the form of data frame(s).
# - Save the optimal values for network config and learning rate in variables called *optimal_layer_config* and *optimal_learning_rate* respectively.

# %% [markdown]
# ### Recommendations
# - You will need to train multiple models for each set of hyperparameter values to get a reliable estimate of the performance.
# - Saving the output of the *.fit()* method allows you to access the values of the metrics.

# %% [markdown]
# Tune your CNN model for network structure and learning rate.

# %%
# Use this cell to tune your CNN model for network structure and learning rate

# Define network configurations
layers_config_list = [
    [32, 64, 128],  # Configuration 1: Increasing number of filters
    [16, 32, 64, 128]  # Configuration 2: More layers with fewer filters
]

# Define learning rates
learning_rate_list = [0.001, 0.01]  # Include the default value

# %%
def create_cnn_model(layers_config, learning_rate):
    model = Sequential()
    
    # First layer
    model.add(Conv2D(layers_config[0], (3, 3), activation='relu', input_shape=(64, 64, 3)))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Add additional layers based on configuration
    for filters in layers_config[1:]:
        model.add(Conv2D(filters, (3, 3), activation='relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(len(label_mapping), activation='softmax'))  # Output layer
    
    # Compile the model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# You should take some time and study the results of your hyperparameter tuning. Once you are satisfied with your analysis, decide on the optimal values of the hyperparameters to use.

# %%
# Use this cell to specify your optimal hyperparameter values
import pandas as pd

# Store performance results
performance_results = []

# Loop through each combination of layers and learning rates
for layers_config in layers_config_list:
    for learning_rate in learning_rate_list:
        # Create the model
        model = create_cnn_model(layers_config, learning_rate)
        
        # Fit the model and store the history
        history = model.fit(X_train_array, y_train_array, 
                            epochs=10, 
                            batch_size=32, 
                            validation_split=0.2,
                            verbose=0)  # Set verbose=0 to avoid printing the output
        
        # Calculate the number of trainable parameters
        trainable_params = model.count_params()
        
        # Record the performance
        performance_results.append({
            'layers_config': str(layers_config),
            'learning_rate': learning_rate,
            'train_accuracy': history.history['accuracy'][-1],
            'val_accuracy': history.history['val_accuracy'][-1],
            'trainable_params': trainable_params
        })

# %%
# Store the values of the optimal hyperparameters
# Convert performance results to DataFrame
results_df = pd.DataFrame(performance_results)

# Display the results
print(results_df)

# Find the optimal configuration based on validation accuracy
optimal_model = results_df.loc[results_df['val_accuracy'].idxmax()]

# Store the optimal hyperparameters
optimal_layer_config = eval(optimal_model['layers_config'])  # Convert string back to list
optimal_learning_rate = optimal_model['learning_rate']

print(f'Optimal Layer Configuration: {optimal_layer_config}')
print(f'Optimal Learning Rate: {optimal_learning_rate}')
# Out:
#        layers_config  learning_rate  train_accuracy  val_accuracy  \
# 0      [32, 64, 128]          0.001        0.940789      0.783626
# 1      [32, 64, 128]          0.010        0.815058      0.628655
# 2  [16, 32, 64, 128]          0.001        0.949561      0.771930
# 3  [16, 32, 64, 128]          0.010        0.422515      0.000000
#
#    trainable_params
# 0            683587
# 1            683587
# 2            163491
# 3            163491
# Optimal Layer Configuration: [32, 64, 128]
# Optimal Learning Rate: 0.001

# %%
#Verify the Number of Parameters
#Make sure the optimal model does not exceed 500,000 parameters:
if optimal_model['trainable_params'] > 500000:
    print("Warning: Optimal model exceeds 500,000 trainable parameters!")
else:
    print("Optimal model is within the parameter limit.")
# Out:
# Warning: Optimal model exceeds 500,000 trainable parameters!

# %% [markdown]
# ### Checklist
# - Decided on the values of hyperparameters over which to tune the model
# - Trained multiple models for each combination of hyperparameters
# - The optimal model has good and consistent validation accuracy
# - The optimal model doesn't have more than 500,000 trainable parameters

# %% [markdown]
# # Stage 6 - Testing
# In this stage, you will train your optimal model multiple times on the augmented data set until you are satisfied with its performance on the validation data. You will then test your optimal model on the hold-out test data set, which has not been used up until this point.

# %% [markdown]
# ## Task 13 - Train your optimal model satisfactorily

# %% [markdown]
# ### Description
#
# In this section, you will train your optimal model on the augmented data set multiple times until you are satisfied with its performance on the validation data.

# %% [markdown]
# ### Requirements
# - Train a CNN model that has a good validation accuracy on the training data set using *optimal_layer_config* and *optimal_learning_rate*.
# - Evaluate the accuracy of this CNN model on the testing data set.

# %% [markdown]
# ### Recommendations
# - You can decide on a minimum validation accuracy that your model must exhibit based on the past performance of your model. You are advised to begin with 80% as a starting threshold.
# - Train your optimal model multiple times till you achieve the required validation accuracy.

# %%
# Use this cell to train your optimal model on the augment data set until you are satisfied with its validation performance
# Define the minimum validation accuracy threshold
min_val_accuracy = 0.80
achieved_accuracy = 0.0
epochs = 20  # You can adjust the number of epochs

while achieved_accuracy < min_val_accuracy:
    # Create the model with the optimal configuration
    model = create_cnn_model(optimal_layer_config, optimal_learning_rate)
    
    # Train the model
    history = model.fit(X_train_array, y_train_array, 
                        epochs=epochs, 
                        batch_size=32, 
                        validation_split=0.2, 
                        verbose=1)  # Set verbose=1 to monitor training progress
    
    # Update the achieved accuracy from the latest validation accuracy
    achieved_accuracy = history.history['val_accuracy'][-1]
    print(f'Current validation accuracy: {achieved_accuracy:.4f}')

print(f'Final validation accuracy achieved: {achieved_accuracy:.4f}')
# Out:
# Epoch 1/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.5719 - loss: 0.9206 - val_accuracy: 0.3187 - val_loss: 1.0533
# Epoch 2/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8077 - loss: 0.5171 - val_accuracy: 0.7515 - val_loss: 0.7197
# Epoch 3/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8612 - loss: 0.3882 - val_accuracy: 0.7661 - val_loss: 0.6849
# Epoch 4/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.8790 - loss: 0.3293 - val_accuracy: 0.8070 - val_loss: 0.4866
# Epoch 5/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9426 - loss: 0.1865 - val_accuracy: 0.7398 - val_loss: 0.6218
# Epoch 6/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9323 - loss: 0.1900 - val_accuracy: 0.7602 - val_loss: 0.6458
# Epoch 7/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9456 - loss: 0.1439 - val_accuracy: 0.5556 - val_loss: 1.5059
# Epoch 8/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9344 - loss: 0.1962 - val_accuracy: 0.7135 - val_loss: 0.8357
# Epoch 9/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9732 - loss: 0.0910 - val_accuracy: 0.8275 - val_loss: 0.6155
# Epoch 10/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9217 - loss: 0.2202 - val_accuracy: 0.7164 - val_loss: 0.8436
# Epoch 11/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9830 - loss: 0.0592 - val_accuracy: 0.8538 - val_loss: 0.4172
# Epoch 12/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9739 - loss: 0.0762 - val_accuracy: 0.7690 - val_loss: 0.7237
# Epoch 13/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9518 - loss: 0.1267 - val_accuracy: 0.6959 - val_loss: 1.0950
# Epoch 14/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9835 - loss: 0.0494 - val_accuracy: 0.7661 - val_loss: 0.8554
# Epoch 15/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9890 - loss: 0.0361 - val_accuracy: 0.8012 - val_loss: 0.6526
# Epoch 16/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.9937 - loss: 0.0292 - val_accuracy: 0.8129 - val_loss: 0.7012
# Epoch 17/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9978 - loss: 0.0141 - val_accuracy: 0.6784 - val_loss: 1.3015
# Epoch 18/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9875 - loss: 0.0306 - val_accuracy: 0.7719 - val_loss: 0.7979
# Epoch 19/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9870 - loss: 0.0332 - val_accuracy: 0.7895 - val_loss: 0.8277
# Epoch 20/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9849 - loss: 0.0433 - val_accuracy: 0.8889 - val_loss: 0.4564
# Current validation accuracy: 0.8889
# Final validation accuracy achieved: 0.8889

# %%
# Use this cell to test your optimal model on the hold-out test data set

# Obtain the perfomance metrics of the optimal model on the testing data set using the "evaluate()" method
# Use this cell to test your optimal model on the hold-out test data set
performance_test = model.evaluate(X_test, y_test)

print('The accuracy of the model on the testing data is {:.4f}'.format(performance_test[1]))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8947 - loss: 0.5204
# The accuracy of the model on the testing data is 0.8889

# %% [markdown]
# ### Checklist
# - Decided on a minimum validation accuracy
# - Trained multiple models till that accuracy is achieved
# - Your optimal model does well on the testing data

# %% [markdown]
# Now that you have completed all the tasks in the assignment, please move on to create your analysis report, and subsequently prepare to submit the required files to the platform.

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\hp\anaconda3\lib\site-packages (4.36.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.111.0)
# Requirement already satisfied: ffmpy in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (1.0.1)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.23.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (3.7.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (3.10.5)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from gradio) (23.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (10.3.0)
# Requirement already satisfied: pydantic>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (2.7.4)
# Requirement already satisfied: pydub in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: ruff>=0.2.2 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.4.9)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (4.12.2)
# Requirement already satisfied: urllib3~=2.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (2.2.2)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio) (0.30.1)
# Requirement already satisfied: fsspec in c:\users\hp\anaconda3\lib\site-packages (from gradio-client==1.0.1->gradio) (2024.6.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in c:\users\hp\anaconda3\lib\site-packages (from gradio-client==1.0.1->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\hp\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in c:\users\hp\anaconda3\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: anyio in c:\users\hp\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.5.0)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.5)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from httpx>=0.24.1->gradio) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\hp\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (4.65.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=2.0->gradio) (2.18.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\hp\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hp\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hp\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in c:\users\hp\anaconda3\lib\site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: fastapi-cli>=0.0.2 in c:\users\hp\anaconda3\lib\site-packages (from fastapi->gradio) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in c:\users\hp\anaconda3\lib\site-packages (from fastapi->gradio) (5.4.0)
# Requirement already satisfied: email_validator>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from fastapi->gradio) (2.1.2)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from email_validator>=2.0.0->fastapi->gradio) (2.6.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn>=0.14.0->gradio) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn>=0.14.0->gradio) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn>=0.14.0->gradio) (0.22.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.0.4)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import numpy as np
import gradio as gr
from tensorflow.keras.models import load_model

class_labels = {0: "Cloudy", 1: "Rainy", 2: "Sunny"}
# Load your trained model
model = load_model('your_model.h5')

# Define the prediction function
def predict(image):
    # Convert the NumPy array to a PIL Image
    img = Image.fromarray(image.astype('uint8'), 'RGB')
    
    # Preprocess the image
    img = img.resize((64, 64))  # Resize to your model's input size
    img_array = np.array(img) / 255.0  # Normalize the image
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    
    # Make prediction
    prediction = model.predict(img_array)
    class_idx = np.argmax(prediction)  # Get the index of the predicted class
    
    return f'Predicted Class: {class_labels[class_idx]}'
  # Map this index to your class names if needed

# Create the Gradio interface
iface = gr.Interface(
    fn=predict,                   # The prediction function
    inputs=gr.Image(),            # Input type
    outputs=gr.Text(),            # Output type
    title="Image Classification",
    description="Upload an image to get the predicted class."
)

# Launch the interface
iface.launch()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Running on local URL:  http://127.0.0.1:7864
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
